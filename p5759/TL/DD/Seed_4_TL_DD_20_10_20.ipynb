# %%
# Load Libraries
import pandas as pd
import numpy as np
import os
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt
from keras.models import load_model

# %%
# Seed
np.random.seed(30)
tf.random.set_seed(30)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Change the current working directory
os.chdir('/content/drive/My Drive/Colab Notebooks/PINN_Active_Passive_Paper/p5759')
# Print the current working directory
print("Current working directory: {0}".format(os.getcwd()))
# Out:
# Current working directory: /content/drive/My Drive/Colab Notebooks/PINN_Active_Passive_Paper/p5759

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
# Load Features
os.chdir('/content/drive/My Drive/Colab Notebooks/PINN_Active_Passive_Paper/p5759/Data')
Data1 = loadmat('p5759_Inputs.mat')
Data2 = loadmat('p5759_Outputs.mat')
Features = pd.DataFrame({'Time':Data1['Time'].ravel().round(2),'K':Data1['K'].ravel().round(2),'V':Data1['V'].ravel().round(2),'AE':Data1['AE'].ravel().round(2),
                         'Amp':Data1['Amp'].ravel().round(2)})
Output = pd.DataFrame({'Time':Data2['Time'].ravel().round(2),'SS':Data2['SS'].ravel().round(2),'ln_V_V0':Data2['ln_V_V0'].ravel().round(2),'TTF':Data2['TTF'].ravel().round(2),
                       'physics_out':Data2['physics_out'].ravel().round(2), 'SR':Data2['SR'].ravel().round(2)})
df = Features.merge(Output, on = 'Time')
df = df[['K','V','AE','Amp','SS','TTF','ln_V_V0','SR','physics_out','Time']]
df_AE = df[['AE','AE']]
df_SS = df[['K','V','AE','Amp','SS']]
df_TTF = df[['K','V','AE','Amp','TTF']]
df_SR = df[['K','V','AE','Amp','ln_V_V0']]
xdf = df[['K','V','AE','Amp']]
ydf = df[['SS','TTF','ln_V_V0']]
print("Input Data:\n", xdf)
print("Target Data:\n",ydf)
# Out:
# Input Data:
#                  K      V     AE       Amp
# 0      3511910.82  23.33   1.50  12313.25
# 1      3511805.49  23.16   1.67  12390.65
# 2         3807.30  16.44   1.67  12433.71
# 3          992.68  16.27   1.33  12425.59
# 4          999.61  16.27   1.33  12417.39
# ...           ...    ...    ...       ...
# 2549  46495304.45  57.63  21.00  14054.81
# 2550  28519703.48  45.56  28.00  14150.11
# 2551  28519724.49  45.56  26.67  14268.53
# 2552  28519838.19  45.57   8.67  14322.32
# 2553  28519979.30  45.56   2.00  14373.05
#
# [2554 rows x 4 columns]
# Target Data:
#           SS   TTF  ln_V_V0
# 0     11.43  0.00   -11.51
# 1     11.46  5.78   -11.51
# 2     11.54  5.67   -11.51
# 3     11.65  5.56   -11.51
# 4     11.73  5.46   -11.51
# ...     ...   ...      ...
# 2549  12.79  0.00   -11.51
# 2550  11.50  0.00     1.45
# 2551  11.33  0.00   -11.51
# 2552  11.41  0.00   -11.51
# 2553  11.52  0.00   -11.51
#
# [2554 rows x 3 columns]

# %%
# Preprocessing (AE)
arr = df_AE.to_numpy()
n_steps = 100
xdf_AE, ydf_AE = create_timesteps(arr, n_steps)

# Preprocessing (SS)
arr = df_SS.to_numpy()
n_steps = 100
xdf, ydf_SS = create_timesteps(arr, n_steps)

# Preprocessing (TTF)
arr = df_TTF.to_numpy()
n_steps = 100
xdf, ydf_TTF = create_timesteps(arr, n_steps)

# Preprocessing (SR)
arr = df_SR.to_numpy()
n_steps = 100
xdf, ydf_SR = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))
print('Target shape (TTF), Y = ', np.shape(ydf_TTF))
print('Target shape (SR), Y = ', np.shape(ydf_SR))
print('Target shape (AE), Y = ', np.shape(ydf_AE))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))

# Reshape AE
in_dim = xdf_AE.shape[1]*xdf_AE.shape[2]
xdf_AE = xdf_AE.reshape((xdf_AE.shape[0], in_dim))
print('After reshaping, xdf_AE = ', np.shape(xdf_AE))
# Out:
# Features shape, X =  (2454, 100, 4)
# Target shape (SS), Y =  (2454,)
# Target shape (TTF), Y =  (2454,)
# Target shape (SR), Y =  (2454,)
# Target shape (AE), Y =  (2454,)
# After reshaping, X =  (2454, 400)
# After reshaping, xdf_AE =  (2454, 100)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.125, shuffle=False)

# Split into train-val-test (TTF)
x_train, x_test, y_train_TTF, y_test_TTF = train_test_split(xdf, ydf_TTF, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_TTF, Y_val_TTF = train_test_split(x_train, y_train_TTF, test_size=0.125, shuffle=False)

# Split into train-val-test (SR)
x_train, x_test, y_train_SR, y_test_SR = train_test_split(xdf, ydf_SR, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_SR, Y_val_SR = train_test_split(x_train, y_train_SR, test_size=0.125, shuffle=False)

# Split into train-val-test (AE)
x_train, x_test, y_train_AE, y_test_AE = train_test_split(xdf, xdf_AE, test_size=0.2, shuffle=False)
X_train, X_val, Y_train_AE, Y_val_AE = train_test_split(x_train, y_train_AE, test_size=0.125, shuffle=False)

# Select Train
X_train = X_train[1226:1717]
Y_train_SS = Y_train_SS[1226:1717]
Y_train_TTF = Y_train_TTF[1226:1717]
Y_train_SR = Y_train_SR[1226:1717]
Y_train_AE = Y_train_AE[1226:1717]

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train)[0])
print("Validation samples:", np.shape(X_val)[0])
print("Testing samples:", np.shape(x_test)[0])
# Out:
# Training samples: 491
# Validation samples: 246
# Testing samples: 491

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler(feature_range=(0, 1))
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %%
# Normalize the output: TTF
scaler_ttf = MinMaxScaler(feature_range=(0, 1))
Y_train_TTF = pd.DataFrame(scaler_ttf.fit_transform(Y_train_TTF.reshape(-1, 1)))
Y_val_TTF = pd.DataFrame(scaler_ttf.transform(Y_val_TTF.reshape(-1, 1)))
y_test_TTF = pd.DataFrame(scaler_ttf.transform(y_test_TTF.reshape(-1, 1)))

# %%
# # Normalize the output: SR
scaler_sr = MinMaxScaler(feature_range=(-1, 1))
Y_train_SR = pd.DataFrame(scaler_sr.fit_transform(Y_train_SR.reshape(-1, 1)))
Y_val_SR = pd.DataFrame(scaler_sr.transform(Y_val_SR.reshape(-1, 1)))
y_test_SR = pd.DataFrame(scaler_sr.transform(y_test_SR.reshape(-1, 1)))

# %%
# Normalize the input: AE
scaler_ae = MinMaxScaler(feature_range=(0, 1))
Y_train_AE = pd.DataFrame(scaler_ae.fit_transform(Y_train_AE))
Y_val_AE = pd.DataFrame(scaler_ae.transform(Y_val_AE))
y_test_AE = pd.DataFrame(scaler_ae.transform(y_test_AE))

# %%
# Train The Model
model = load_model('/content/drive/My Drive/Colab Notebooks/PINN_Active_Passive_Paper/p5759/Data/DD_Transfer_model_80_10_10.h5')

model.compile(loss='mse', optimizer=tf.keras.optimizers.legacy.Adam(1e-3))

start_time = time.time()
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
callbacks_list = [earlystop]
history = model.fit([X_train,Y_train_AE],[Y_train_SS,Y_train_TTF,Y_train_SR], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val,Y_val_AE],[Y_val_SS,Y_val_TTF,Y_val_SR]), verbose=1)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
end_time = time.time()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Train on 491 samples, validate on 246 samples
# Epoch 1/100
# 491/491 [==============================] - 1s 1ms/sample - loss: 0.0960 - dense_5_loss: 0.0383 - dense_6_loss: 0.0529 - dense_12_loss: 0.0025 - val_loss: 0.0569 - val_dense_5_loss: 0.0403 - val_dense_6_loss: 0.0164 - val_dense_12_loss: 0.0013
# Epoch 2/100
# 491/491 [==============================] - 0s 135us/sample - loss: 0.0435 - dense_5_loss: 0.0191 - dense_6_loss: 0.0237 - dense_12_loss: 2.2792e-04 - val_loss: 0.0467 - val_dense_5_loss: 0.0270 - val_dense_6_loss: 0.0205 - val_dense_12_loss: 8.8975e-04
# Epoch 3/100
#  32/491 [>.............................] - ETA: 0s - loss: 0.0571 - dense_5_loss: 0.0192 - dense_6_loss: 0.0378 - dense_12_loss: 1.3054e-04
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 491/491 [==============================] - 0s 125us/sample - loss: 0.0303 - dense_5_loss: 0.0130 - dense_6_loss: 0.0164 - dense_12_loss: 1.8989e-04 - val_loss: 0.0561 - val_dense_5_loss: 0.0228 - val_dense_6_loss: 0.0318 - val_dense_12_loss: 7.7869e-04
# Epoch 4/100
# 491/491 [==============================] - 0s 125us/sample - loss: 0.0219 - dense_5_loss: 0.0098 - dense_6_loss: 0.0117 - dense_12_loss: 1.5261e-04 - val_loss: 0.0476 - val_dense_5_loss: 0.0160 - val_dense_6_loss: 0.0315 - val_dense_12_loss: 6.7839e-04
# Epoch 5/100
# 491/491 [==============================] - 0s 136us/sample - loss: 0.0159 - dense_5_loss: 0.0076 - dense_6_loss: 0.0077 - dense_12_loss: 1.2620e-04 - val_loss: 0.0325 - val_dense_5_loss: 0.0106 - val_dense_6_loss: 0.0210 - val_dense_12_loss: 6.3809e-04
# Epoch 6/100
# 491/491 [==============================] - 0s 126us/sample - loss: 0.0122 - dense_5_loss: 0.0073 - dense_6_loss: 0.0060 - dense_12_loss: 9.3481e-05 - val_loss: 0.0308 - val_dense_5_loss: 0.0088 - val_dense_6_loss: 0.0211 - val_dense_12_loss: 5.8592e-04
# Epoch 7/100
# 491/491 [==============================] - 0s 125us/sample - loss: 0.0107 - dense_5_loss: 0.0055 - dense_6_loss: 0.0049 - dense_12_loss: 8.3481e-05 - val_loss: 0.0417 - val_dense_5_loss: 0.0177 - val_dense_6_loss: 0.0233 - val_dense_12_loss: 5.7369e-04
# Epoch 8/100
# 491/491 [==============================] - 0s 122us/sample - loss: 0.0092 - dense_5_loss: 0.0046 - dense_6_loss: 0.0045 - dense_12_loss: 6.6042e-05 - val_loss: 0.0335 - val_dense_5_loss: 0.0080 - val_dense_6_loss: 0.0248 - val_dense_12_loss: 5.6961e-04
# Epoch 9/100
# 491/491 [==============================] - 0s 107us/sample - loss: 0.0081 - dense_5_loss: 0.0042 - dense_6_loss: 0.0038 - dense_12_loss: 5.9065e-05 - val_loss: 0.0248 - val_dense_5_loss: 0.0114 - val_dense_6_loss: 0.0127 - val_dense_12_loss: 5.1237e-04
# Epoch 10/100
# 491/491 [==============================] - 0s 132us/sample - loss: 0.0076 - dense_5_loss: 0.0040 - dense_6_loss: 0.0034 - dense_12_loss: 6.6350e-05 - val_loss: 0.0242 - val_dense_5_loss: 0.0075 - val_dense_6_loss: 0.0159 - val_dense_12_loss: 5.2517e-04
# Epoch 11/100
# 491/491 [==============================] - 0s 111us/sample - loss: 0.0067 - dense_5_loss: 0.0035 - dense_6_loss: 0.0031 - dense_12_loss: 5.2884e-05 - val_loss: 0.0234 - val_dense_5_loss: 0.0053 - val_dense_6_loss: 0.0175 - val_dense_12_loss: 4.7144e-04
# Epoch 12/100
# 491/491 [==============================] - 0s 121us/sample - loss: 0.0061 - dense_5_loss: 0.0032 - dense_6_loss: 0.0028 - dense_12_loss: 3.8665e-05 - val_loss: 0.0212 - val_dense_5_loss: 0.0071 - val_dense_6_loss: 0.0139 - val_dense_12_loss: 5.1183e-04
# Epoch 13/100
# 491/491 [==============================] - 0s 118us/sample - loss: 0.0058 - dense_5_loss: 0.0029 - dense_6_loss: 0.0027 - dense_12_loss: 4.1101e-05 - val_loss: 0.0196 - val_dense_5_loss: 0.0048 - val_dense_6_loss: 0.0145 - val_dense_12_loss: 5.2083e-04
# Epoch 14/100
# 491/491 [==============================] - 0s 117us/sample - loss: 0.0057 - dense_5_loss: 0.0032 - dense_6_loss: 0.0024 - dense_12_loss: 3.4344e-05 - val_loss: 0.0188 - val_dense_5_loss: 0.0046 - val_dense_6_loss: 0.0141 - val_dense_12_loss: 4.5068e-04
# Epoch 15/100
# 491/491 [==============================] - 0s 130us/sample - loss: 0.0055 - dense_5_loss: 0.0030 - dense_6_loss: 0.0022 - dense_12_loss: 3.4866e-05 - val_loss: 0.0212 - val_dense_5_loss: 0.0051 - val_dense_6_loss: 0.0155 - val_dense_12_loss: 4.2871e-04
# Epoch 16/100
# 491/491 [==============================] - 0s 125us/sample - loss: 0.0049 - dense_5_loss: 0.0026 - dense_6_loss: 0.0021 - dense_12_loss: 3.2809e-05 - val_loss: 0.0233 - val_dense_5_loss: 0.0056 - val_dense_6_loss: 0.0171 - val_dense_12_loss: 4.4168e-04
# Epoch 17/100
# 491/491 [==============================] - 0s 127us/sample - loss: 0.0041 - dense_5_loss: 0.0021 - dense_6_loss: 0.0019 - dense_12_loss: 3.4046e-05 - val_loss: 0.0235 - val_dense_5_loss: 0.0047 - val_dense_6_loss: 0.0186 - val_dense_12_loss: 4.1722e-04
# Epoch 18/100
# 491/491 [==============================] - 0s 113us/sample - loss: 0.0039 - dense_5_loss: 0.0019 - dense_6_loss: 0.0019 - dense_12_loss: 2.8499e-05 - val_loss: 0.0184 - val_dense_5_loss: 0.0061 - val_dense_6_loss: 0.0116 - val_dense_12_loss: 4.1769e-04
# Epoch 19/100
# 491/491 [==============================] - 0s 113us/sample - loss: 0.0035 - dense_5_loss: 0.0018 - dense_6_loss: 0.0016 - dense_12_loss: 2.3234e-05 - val_loss: 0.0167 - val_dense_5_loss: 0.0050 - val_dense_6_loss: 0.0111 - val_dense_12_loss: 4.0860e-04
# Epoch 20/100
# 491/491 [==============================] - 0s 156us/sample - loss: 0.0032 - dense_5_loss: 0.0016 - dense_6_loss: 0.0015 - dense_12_loss: 2.2168e-05 - val_loss: 0.0184 - val_dense_5_loss: 0.0056 - val_dense_6_loss: 0.0127 - val_dense_12_loss: 4.8654e-04
# Epoch 21/100
# 491/491 [==============================] - 0s 128us/sample - loss: 0.0030 - dense_5_loss: 0.0015 - dense_6_loss: 0.0014 - dense_12_loss: 2.0740e-05 - val_loss: 0.0122 - val_dense_5_loss: 0.0043 - val_dense_6_loss: 0.0077 - val_dense_12_loss: 4.4046e-04
# Epoch 22/100
# 491/491 [==============================] - 0s 155us/sample - loss: 0.0028 - dense_5_loss: 0.0015 - dense_6_loss: 0.0013 - dense_12_loss: 1.9291e-05 - val_loss: 0.0165 - val_dense_5_loss: 0.0092 - val_dense_6_loss: 0.0066 - val_dense_12_loss: 4.4379e-04
# Epoch 23/100
# 491/491 [==============================] - 0s 126us/sample - loss: 0.0027 - dense_5_loss: 0.0015 - dense_6_loss: 0.0012 - dense_12_loss: 1.9682e-05 - val_loss: 0.0170 - val_dense_5_loss: 0.0075 - val_dense_6_loss: 0.0087 - val_dense_12_loss: 4.0553e-04
# Epoch 24/100
# 491/491 [==============================] - 0s 117us/sample - loss: 0.0027 - dense_5_loss: 0.0015 - dense_6_loss: 0.0011 - dense_12_loss: 2.2267e-05 - val_loss: 0.0131 - val_dense_5_loss: 0.0047 - val_dense_6_loss: 0.0081 - val_dense_12_loss: 4.3667e-04
# Epoch 25/100
# 491/491 [==============================] - 0s 120us/sample - loss: 0.0026 - dense_5_loss: 0.0015 - dense_6_loss: 0.0011 - dense_12_loss: 2.2886e-05 - val_loss: 0.0112 - val_dense_5_loss: 0.0047 - val_dense_6_loss: 0.0061 - val_dense_12_loss: 3.8939e-04
# Epoch 26/100
# 491/491 [==============================] - 0s 124us/sample - loss: 0.0024 - dense_5_loss: 0.0014 - dense_6_loss: 9.3945e-04 - dense_12_loss: 2.2484e-05 - val_loss: 0.0117 - val_dense_5_loss: 0.0036 - val_dense_6_loss: 0.0078 - val_dense_12_loss: 4.6241e-04
# Epoch 27/100
# 491/491 [==============================] - 0s 122us/sample - loss: 0.0021 - dense_5_loss: 0.0012 - dense_6_loss: 8.8254e-04 - dense_12_loss: 1.5672e-05 - val_loss: 0.0111 - val_dense_5_loss: 0.0039 - val_dense_6_loss: 0.0068 - val_dense_12_loss: 4.0895e-04
# Epoch 28/100
# 491/491 [==============================] - 0s 124us/sample - loss: 0.0023 - dense_5_loss: 0.0014 - dense_6_loss: 8.4342e-04 - dense_12_loss: 1.7437e-05 - val_loss: 0.0106 - val_dense_5_loss: 0.0045 - val_dense_6_loss: 0.0060 - val_dense_12_loss: 4.2143e-04
# Epoch 29/100
# 491/491 [==============================] - 0s 125us/sample - loss: 0.0019 - dense_5_loss: 0.0011 - dense_6_loss: 7.6334e-04 - dense_12_loss: 1.6031e-05 - val_loss: 0.0102 - val_dense_5_loss: 0.0043 - val_dense_6_loss: 0.0052 - val_dense_12_loss: 4.0766e-04
# Epoch 30/100
# 491/491 [==============================] - 0s 125us/sample - loss: 0.0017 - dense_5_loss: 9.7865e-04 - dense_6_loss: 6.7446e-04 - dense_12_loss: 1.5583e-05 - val_loss: 0.0114 - val_dense_5_loss: 0.0056 - val_dense_6_loss: 0.0053 - val_dense_12_loss: 3.9588e-04
# Epoch 31/100
# 491/491 [==============================] - 0s 124us/sample - loss: 0.0016 - dense_5_loss: 9.1940e-04 - dense_6_loss: 6.4001e-04 - dense_12_loss: 1.5368e-05 - val_loss: 0.0101 - val_dense_5_loss: 0.0047 - val_dense_6_loss: 0.0051 - val_dense_12_loss: 3.9440e-04
# Epoch 32/100
# 491/491 [==============================] - 0s 132us/sample - loss: 0.0014 - dense_5_loss: 8.5543e-04 - dense_6_loss: 5.9629e-04 - dense_12_loss: 1.3492e-05 - val_loss: 0.0147 - val_dense_5_loss: 0.0089 - val_dense_6_loss: 0.0052 - val_dense_12_loss: 4.3131e-04
# Epoch 33/100
# 491/491 [==============================] - 0s 109us/sample - loss: 0.0014 - dense_5_loss: 8.2037e-04 - dense_6_loss: 5.8453e-04 - dense_12_loss: 1.4605e-05 - val_loss: 0.0096 - val_dense_5_loss: 0.0045 - val_dense_6_loss: 0.0046 - val_dense_12_loss: 4.2892e-04
# Epoch 34/100
# 491/491 [==============================] - 0s 150us/sample - loss: 0.0016 - dense_5_loss: 0.0010 - dense_6_loss: 5.3507e-04 - dense_12_loss: 1.6737e-05 - val_loss: 0.0128 - val_dense_5_loss: 0.0095 - val_dense_6_loss: 0.0030 - val_dense_12_loss: 3.8614e-04
# Epoch 35/100
# 491/491 [==============================] - 0s 117us/sample - loss: 0.0015 - dense_5_loss: 9.4180e-04 - dense_6_loss: 5.6816e-04 - dense_12_loss: 1.4259e-05 - val_loss: 0.0081 - val_dense_5_loss: 0.0046 - val_dense_6_loss: 0.0030 - val_dense_12_loss: 3.8838e-04
# Epoch 36/100
# 491/491 [==============================] - 0s 118us/sample - loss: 0.0014 - dense_5_loss: 8.3467e-04 - dense_6_loss: 5.7082e-04 - dense_12_loss: 1.5530e-05 - val_loss: 0.0094 - val_dense_5_loss: 0.0054 - val_dense_6_loss: 0.0035 - val_dense_12_loss: 4.0426e-04
# Epoch 37/100
# 491/491 [==============================] - 0s 122us/sample - loss: 0.0014 - dense_5_loss: 8.4404e-04 - dense_6_loss: 4.9858e-04 - dense_12_loss: 1.5020e-05 - val_loss: 0.0108 - val_dense_5_loss: 0.0056 - val_dense_6_loss: 0.0048 - val_dense_12_loss: 3.8582e-04
# Epoch 38/100
# 491/491 [==============================] - 0s 131us/sample - loss: 0.0012 - dense_5_loss: 6.3460e-04 - dense_6_loss: 5.2590e-04 - dense_12_loss: 1.3649e-05 - val_loss: 0.0095 - val_dense_5_loss: 0.0065 - val_dense_6_loss: 0.0026 - val_dense_12_loss: 3.7667e-04
# Epoch 39/100
# 491/491 [==============================] - 0s 116us/sample - loss: 0.0012 - dense_5_loss: 7.4711e-04 - dense_6_loss: 4.2554e-04 - dense_12_loss: 1.2021e-05 - val_loss: 0.0099 - val_dense_5_loss: 0.0066 - val_dense_6_loss: 0.0028 - val_dense_12_loss: 3.7863e-04
# Epoch 40/100
# 491/491 [==============================] - 0s 121us/sample - loss: 0.0010 - dense_5_loss: 6.3129e-04 - dense_6_loss: 3.6858e-04 - dense_12_loss: 1.2035e-05 - val_loss: 0.0145 - val_dense_5_loss: 0.0114 - val_dense_6_loss: 0.0027 - val_dense_12_loss: 4.2305e-04
# Epoch 41/100
# 491/491 [==============================] - 0s 119us/sample - loss: 0.0013 - dense_5_loss: 8.6982e-04 - dense_6_loss: 3.9784e-04 - dense_12_loss: 1.1488e-05 - val_loss: 0.0170 - val_dense_5_loss: 0.0146 - val_dense_6_loss: 0.0026 - val_dense_12_loss: 3.9017e-04
# Epoch 42/100
# 491/491 [==============================] - 0s 122us/sample - loss: 0.0011 - dense_5_loss: 7.3468e-04 - dense_6_loss: 3.8790e-04 - dense_12_loss: 1.4731e-05 - val_loss: 0.0124 - val_dense_5_loss: 0.0086 - val_dense_6_loss: 0.0034 - val_dense_12_loss: 4.4923e-04
# Epoch 43/100
# 491/491 [==============================] - 0s 123us/sample - loss: 9.3863e-04 - dense_5_loss: 5.3021e-04 - dense_6_loss: 3.8073e-04 - dense_12_loss: 1.2206e-05 - val_loss: 0.0126 - val_dense_5_loss: 0.0093 - val_dense_6_loss: 0.0029 - val_dense_12_loss: 3.8795e-04
# Epoch 44/100
# 491/491 [==============================] - 0s 118us/sample - loss: 9.8750e-04 - dense_5_loss: 6.5440e-04 - dense_6_loss: 3.7698e-04 - dense_12_loss: 1.3461e-05 - val_loss: 0.0096 - val_dense_5_loss: 0.0059 - val_dense_6_loss: 0.0033 - val_dense_12_loss: 4.1679e-04
# Epoch 45/100
# 491/491 [==============================] - 0s 121us/sample - loss: 0.0014 - dense_5_loss: 0.0010 - dense_6_loss: 3.3958e-04 - dense_12_loss: 1.4424e-05 - val_loss: 0.0086 - val_dense_5_loss: 0.0057 - val_dense_6_loss: 0.0024 - val_dense_12_loss: 4.3241e-04
# Epoch 46/100
# 491/491 [==============================] - 0s 119us/sample - loss: 0.0012 - dense_5_loss: 8.9018e-04 - dense_6_loss: 3.7072e-04 - dense_12_loss: 1.7432e-05 - val_loss: 0.0119 - val_dense_5_loss: 0.0089 - val_dense_6_loss: 0.0026 - val_dense_12_loss: 3.6800e-04
# Epoch 47/100
# 491/491 [==============================] - 0s 150us/sample - loss: 0.0014 - dense_5_loss: 0.0011 - dense_6_loss: 3.2610e-04 - dense_12_loss: 2.5107e-05 - val_loss: 0.0207 - val_dense_5_loss: 0.0178 - val_dense_6_loss: 0.0026 - val_dense_12_loss: 3.6903e-04
# Epoch 48/100
# 491/491 [==============================] - 0s 125us/sample - loss: 0.0011 - dense_5_loss: 7.7818e-04 - dense_6_loss: 2.7306e-04 - dense_12_loss: 1.3294e-05 - val_loss: 0.0143 - val_dense_5_loss: 0.0117 - val_dense_6_loss: 0.0023 - val_dense_12_loss: 3.5002e-04
# Epoch 49/100
# 491/491 [==============================] - 0s 138us/sample - loss: 9.1193e-04 - dense_5_loss: 6.0518e-04 - dense_6_loss: 2.8828e-04 - dense_12_loss: 1.5036e-05 - val_loss: 0.0105 - val_dense_5_loss: 0.0079 - val_dense_6_loss: 0.0022 - val_dense_12_loss: 3.8012e-04
# Epoch 50/100
# 491/491 [==============================] - 0s 130us/sample - loss: 8.0169e-04 - dense_5_loss: 4.9370e-04 - dense_6_loss: 2.8885e-04 - dense_12_loss: 9.3169e-06 - val_loss: 0.0144 - val_dense_5_loss: 0.0115 - val_dense_6_loss: 0.0026 - val_dense_12_loss: 3.5092e-04
# Epoch 51/100
# 491/491 [==============================] - 0s 122us/sample - loss: 8.7482e-04 - dense_5_loss: 5.7857e-04 - dense_6_loss: 2.8867e-04 - dense_12_loss: 1.2877e-05 - val_loss: 0.0104 - val_dense_5_loss: 0.0077 - val_dense_6_loss: 0.0024 - val_dense_12_loss: 3.7427e-04
# Epoch 52/100
# 491/491 [==============================] - 0s 123us/sample - loss: 8.0746e-04 - dense_5_loss: 5.2613e-04 - dense_6_loss: 2.6448e-04 - dense_12_loss: 1.3918e-05 - val_loss: 0.0113 - val_dense_5_loss: 0.0081 - val_dense_6_loss: 0.0030 - val_dense_12_loss: 3.6477e-04
# Epoch 53/100
# 491/491 [==============================] - 0s 125us/sample - loss: 7.5270e-04 - dense_5_loss: 5.0293e-04 - dense_6_loss: 2.5581e-04 - dense_12_loss: 1.3565e-05 - val_loss: 0.0140 - val_dense_5_loss: 0.0114 - val_dense_6_loss: 0.0024 - val_dense_12_loss: 3.6522e-04
# Epoch 54/100
# 491/491 [==============================] - 0s 128us/sample - loss: 7.2434e-04 - dense_5_loss: 4.6714e-04 - dense_6_loss: 2.2976e-04 - dense_12_loss: 1.2841e-05 - val_loss: 0.0134 - val_dense_5_loss: 0.0106 - val_dense_6_loss: 0.0024 - val_dense_12_loss: 3.5701e-04
# Epoch 55/100
# 491/491 [==============================] - 0s 157us/sample - loss: 6.8965e-04 - dense_5_loss: 4.3340e-04 - dense_6_loss: 2.4070e-04 - dense_12_loss: 1.0757e-05 - val_loss: 0.0134 - val_dense_5_loss: 0.0108 - val_dense_6_loss: 0.0021 - val_dense_12_loss: 4.2415e-04
# Epoch 55: early stopping
# ---Training time: 6.88418865 seconds ---

# %%
# Predictions: Training
y_predtrain = model.predict([X_train,Y_train_AE])
y_predtrain_SS = np.array(y_predtrain)[0,]
y_predtrain_TTF =np.array(y_predtrain)[1,]
y_predtrain_SR =np.array(y_predtrain)[2,]

# Predictions: Validation
y_predval = model.predict([X_val,Y_val_AE])
y_predval_SS = np.array(y_predval)[0,]
y_predval_TTF =np.array(y_predval)[1,]
y_predval_SR =np.array(y_predval)[2,]

# Predictions: Testing
y_predtest = model.predict([x_test,y_test_AE])
y_predtest_SS = np.array(y_predtest)[0,]
y_predtest_TTF =np.array(y_predtest)[1,]
y_predtest_SR =np.array(y_predtest)[2,]
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
# Inverse scaling: SS
Y_train_SS = scaler_ss.inverse_transform(Y_train_SS)
Y_val_SS = scaler_ss.inverse_transform(Y_val_SS)
y_test_SS = scaler_ss.inverse_transform(y_test_SS)
y_predtrain_SS = scaler_ss.inverse_transform(y_predtrain_SS)
y_predval_SS = scaler_ss.inverse_transform(y_predval_SS)
y_predtest_SS = scaler_ss.inverse_transform(y_predtest_SS)

# Inverse scaling: TTF
Y_train_TTF = scaler_ttf.inverse_transform(Y_train_TTF)
Y_val_TTF = scaler_ttf.inverse_transform(Y_val_TTF)
y_test_TTF = scaler_ttf.inverse_transform(y_test_TTF)
y_predtrain_TTF = scaler_ttf.inverse_transform(y_predtrain_TTF)
y_predval_TTF = scaler_ttf.inverse_transform(y_predval_TTF)
y_predtest_TTF = scaler_ttf.inverse_transform(y_predtest_TTF)

# Inverse scaling: SR
Y_train_SR = scaler_sr.inverse_transform(Y_train_SR)
Y_val_SR = scaler_sr.inverse_transform(Y_val_SR)
y_test_SR = scaler_sr.inverse_transform(y_test_SR)
y_predtrain_SR = scaler_sr.inverse_transform(y_predtrain_SR)
y_predval_SR = scaler_sr.inverse_transform(y_predval_SR)
y_predtest_SR = scaler_sr.inverse_transform(y_predtest_SR)

# %%
# Model Performance: Training
train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

train_r2_TTF = r2_score(Y_train_TTF, y_predtrain_TTF)
train_rmse_TTF = np.sqrt(mean_squared_error(Y_train_TTF, y_predtrain_TTF))

train_r2_SR = r2_score(Y_train_SR, y_predtrain_SR)
train_rmse_SR = np.sqrt(mean_squared_error(Y_train_SR, y_predtrain_SR))

# Model Performance: Validation
val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

val_r2_TTF = r2_score(Y_val_TTF, y_predval_TTF)
val_rmse_TTF = np.sqrt(mean_squared_error(Y_val_TTF, y_predval_TTF))

val_r2_SR = r2_score(Y_val_SR, y_predval_SR)
val_rmse_SR = np.sqrt(mean_squared_error(Y_val_SR, y_predval_SR))

# Model Performance: Testing
test_r2_SS = r2_score(y_test_SS, y_predtest_SS)
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))

test_r2_TTF = r2_score(y_test_TTF, y_predtest_TTF)
test_rmse_TTF = np.sqrt(mean_squared_error(y_test_TTF, y_predtest_TTF))

test_r2_SR = r2_score(y_test_SR, y_predtest_SR)
test_rmse_SR = np.sqrt(mean_squared_error(y_test_SR, y_predtest_SR))

# %%
# Print R2 Results
print("R2 scores: Train (SS) - %0.5f, Train (TTF) - %0.5f, Train (SR) - %0.5f" %(train_r2_SS, train_r2_TTF, train_r2_SR))
print("R2 scores: Val (SS) - %0.5f, Val (TTF) - %0.5f, Val (SR) - %0.5f" %(val_r2_SS, val_r2_TTF, val_r2_SR))
print("R2 scores: Test (SS) - %0.5f, Test (TTF) - %0.5f, Test (SR) - %0.5f" %(test_r2_SS, test_r2_TTF, test_r2_SR))
# Out:
# R2 scores: Train (SS) - 0.99289, Train (TTF) - 0.99729, Train (SR) - 0.99978
# R2 scores: Val (SS) - 0.84535, Val (TTF) - 0.97779, Val (SR) - 0.99404
# R2 scores: Test (SS) - 0.69171, Test (TTF) - 0.85911, Test (SR) - 0.90969

# %%
# Print RMSE Results
print("RMSE: Train (SS) - %0.5f, Train (TTF) - %0.5f, Train (SR) - %0.5f" %(train_rmse_SS, train_rmse_TTF, train_rmse_SR))
print("RMSE: Val (SS) - %0.5f, Val (TTF) - %0.5f, Val (SR) - %0.5f" %(val_rmse_SS, val_rmse_TTF, val_rmse_SR))
print("RMSE: Test (SS) - %0.5f, Test (TTF) - %0.5f, Test (SR) - %0.5f" %(test_rmse_SS, test_rmse_TTF, test_rmse_SR))
# Out:
# RMSE: Train (SS) - 0.02987, Train (TTF) - 0.10035, Train (SR) - 0.02281
# RMSE: Val (SS) - 0.14648, Val (TTF) - 0.30343, Val (SR) - 0.12766
# RMSE: Test (SS) - 0.21426, Test (TTF) - 0.76826, Test (SR) - 0.51502

# %%
# Overall plot:
ttime = df['Time'][n_steps:]
t1, testtime = train_test_split(ttime, test_size=0.2, shuffle=False)
traintime, valtime = train_test_split(t1, test_size=0.125, shuffle=False)

traintime = traintime[1226:1717]

fig = plt.figure(1, figsize=(20,6))
plt.plot(ttime, ydf_SS)
plt.plot(traintime, y_predtrain_SS)
plt.plot(valtime, y_predval_SS)
plt.plot(testtime, y_predtest_SS)
plt.xlabel('Time (s)')
plt.ylabel('Shear Stress (MPa)')
plt.legend(['Ground truth', 'Train Prediction', 'Validation Prediction', 'Test Prediction'])

fig = plt.figure(2, figsize=(20,6))
plt.plot(ttime, ydf_TTF)
plt.plot(traintime, y_predtrain_TTF)
plt.plot(valtime,  y_predval_TTF)
plt.plot(testtime, y_predtest_TTF)
plt.xlabel('Time (s)')
plt.ylabel('TTF (s)')
plt.legend(['Ground truth', 'Train Prediction', 'Validation Prediction', 'Test Prediction'])

ydf_SR = np.exp(ydf_SR)*10;
y_predtrain_SR = np.exp(y_predtrain_SR)*10;
y_predval_SR = np.exp(y_predval_SR)*10;
y_predtest_SR = np.exp(y_predtest_SR)*10;

fig = plt.figure(3, figsize=(20,6))
plt.plot(ttime, ydf_SR)
plt.plot(traintime, y_predtrain_SR)
plt.plot(valtime,  y_predval_SR)
plt.plot(testtime, y_predtest_SR)
plt.xlabel('Time (s)')
plt.ylabel('Slip Rate (um/s)')
plt.legend(['Ground truth', 'Train Prediction', 'Validation Prediction', 'Test Prediction'])

# %%
# # Individual plot: SS

def results_plot(fig_no, t, gt, pred, title, col):
  fig = plt.figure(fig_no, figsize=(20,6))
  plt.plot(t, gt)
  plt.plot(t, pred, col)
  plt.xlabel('Time (s)')
  plt.ylabel('Shear Stress (MPa)')
  plt.legend(['Ground truth', 'Predicted'])
  plt.title(title)

results_plot(1, traintime, Y_train_SS, y_predtrain_SS, 'Training data', '')
results_plot(2, valtime, Y_val_SS, y_predval_SS, 'Validation data', 'g')
results_plot(3, testtime, y_test_SS, y_predtest_SS, 'Testing data', 'r')

# %%
# # Individual plot: TTF

def results_plot(fig_no, t, gt, pred, title, col):
  fig = plt.figure(fig_no, figsize=(20,6))
  plt.plot(t, gt)
  plt.plot(t, pred, col)
  plt.xlabel('Time (s)')
  plt.ylabel('TTF (s)')
  plt.legend(['Ground truth', 'Predicted'])
  plt.title(title)

results_plot(1, traintime, Y_train_TTF, y_predtrain_TTF, 'Training data', '')
results_plot(2, valtime, Y_val_TTF, y_predval_TTF, 'Validation data', 'g')
results_plot(3, testtime, y_test_TTF, y_predtest_TTF, 'Testing data', 'r')

# %%
# # Individual plot: SR
Y_train_SR = np.exp(Y_train_SR)*10;
Y_val_SR = np.exp(Y_val_SR)*10;
y_test_SR = np.exp(y_test_SR)*10;

def results_plot(fig_no, t, gt, pred, title, col):
  fig = plt.figure(fig_no, figsize=(20,6))
  plt.plot(t, gt)
  plt.plot(t, pred, col)
  plt.xlabel('Time (s)')
  plt.ylabel('Slip Rate (um/s)')
  plt.legend(['Ground truth', 'Predicted'])
  plt.title(title)

results_plot(1, traintime, Y_train_SR, y_predtrain_SR, 'Training data', '')
results_plot(2, valtime, Y_val_SR, y_predval_SR, 'Validation data', 'g')
results_plot(3, testtime, y_test_SR, y_predtest_SR, 'Testing data', 'r')
