# %%
# Load Libraries
import pandas as pd
import numpy as np
import os
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt

# %%
# Seed
np.random.seed(0)
tf.random.set_seed(0)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Change the current working directory
os.chdir('/content/drive/My Drive/Colab Notebooks/PINN_Active_Passive_Paper/p5763')
# Print the current working directory
print("Current working directory: {0}".format(os.getcwd()))
# Out:
# Current working directory: /content/drive/My Drive/Colab Notebooks/PINN_Active_Passive_Paper/p5763

# %%
# Function: Create Data History
def create_timesteps_pre(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x,dtype=object), np.array(y,dtype=object)

# %%
# Function: Create Data History
def create_timesteps(data, data1, n_steps, step):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :], data1[(end_ix):(end_ix + step),:]
		x.append(x1)
		y.append(y1)
	return np.array(x,dtype=object), np.array(y,dtype=object)

# %%
# Load Features
os.chdir('/content/drive/My Drive/Colab Notebooks/PINN_Active_Passive_Paper/p5763/Data')
Data1 = loadmat('p5763_Set1_Inputs.mat')
Data2 = loadmat('p5763_Set1_Outputs.mat')
Features = pd.DataFrame({'Time':Data1['Time'].ravel().round(2),'K':Data1['K'].ravel().round(2),'V':Data1['V'].ravel().round(2),'AE':Data1['AE'].ravel().round(2),
                         'ln_V0_Theta':Data1['ln_V0_Theta'].ravel().round(2)})
Output = pd.DataFrame({'Time':Data2['Time'].ravel().round(2),'SS':Data2['SS'].ravel().round(2),'ln_V_V0':Data2['ln_V_V0'].ravel().round(2),'TTF':Data2['TTF'].ravel().round(2),
                       'physics_out':Data2['physics_out'].ravel().round(2),'SR':Data2['SR'].ravel().round(2)})
df = Features.merge(Output, on = 'Time')
df = df[['K','V','AE','ln_V0_Theta','SS','TTF','ln_V_V0','SR','physics_out','Time']]
df_AE = df[['AE','AE']]
df_SS = df[['K','V','AE','ln_V0_Theta','SS']]
df_SS_1 = df[['SS']]
df_TTF = df[['K','V','AE','ln_V0_Theta','TTF']]
df_TTF_1 = df[['TTF']]
df_SR = df[['K','V','AE','ln_V_V0']]
df_SR_Org = df[['K','V','AE','SR']]
df_A = df[['K','V','AE','ln_V0_Theta']]
df_PhyOut = df[['K','V','AE','ln_V0_Theta','physics_out']]
xdf = df[['K','V','AE','ln_V0_Theta']]
ydf = df[['SS','TTF','ln_V_V0']]
print("Input Data:\n", xdf)
print("Target Data:\n",ydf)
# Out:
# Input Data:
#              K      V    AE  ln_V0_Theta
# 0     5957.24  17.78  2.00         9.95
# 1     5960.89  17.79  2.00         9.94
# 2     6214.84  17.81  2.00         9.94
# 3     4543.97  17.74  2.00         9.95
# 4     4554.15  17.76  1.67         9.94
# ...       ...    ...   ...          ...
# 9495  1033.99  16.82  2.00         9.75
# 9496  1032.72  16.81  2.00         9.77
# 9497  1032.13  16.81  1.67         9.76
# 9498  1032.36  16.81  1.67         9.74
# 9499  1114.37  16.83  1.50         9.74
#
# [9500 rows x 4 columns]
# Target Data:
#          SS   TTF  ln_V_V0
# 0     6.05  0.00   -11.51
# 1     6.06  0.00   -11.51
# 2     6.06  0.00   -11.51
# 3     6.07  0.00   -11.51
# 4     6.07  0.00   -11.51
# ...    ...   ...      ...
# 9495  5.92  6.55   -11.51
# 9496  5.92  6.45   -11.51
# 9497  5.93  6.34   -11.51
# 9498  5.93  6.23   -11.51
# 9499  5.94  6.12   -11.51
#
# [9500 rows x 3 columns]

# %%
n_steps = 100 # History for input features
step = 200  # Steps to predict in future

# Preprocessing (AE)
arr = df_AE.to_numpy()
xdf_AE, ydf_AE = create_timesteps_pre(arr, n_steps)

# Preprocessing (SS)
arr = df_SS.to_numpy()
arr1 = df_SS_1.to_numpy()
arr1.transpose()
xdf, ydf_SS = create_timesteps(arr, arr1, n_steps, step)

# Preprocessing (TTF)
arr = df_TTF.to_numpy()
arr1 = df_TTF_1.to_numpy()
arr1.transpose()
xdf, ydf_TTF = create_timesteps(arr, arr1, n_steps, step)

# # Preprocessing (SR)
arr = df_SR.to_numpy()
xdf, ydf_SR = create_timesteps_pre(arr, n_steps)

# Preprocessing (SR_Org)
arr = df_SR_Org.to_numpy()
xdf, ydf_SR_Org = create_timesteps_pre(arr, n_steps)

# Preprocessing (A)
arr = df_A.to_numpy()
xdf, Adf = create_timesteps_pre(arr, n_steps)

# Preprocessing (Physics_Out)
arr = df_PhyOut.to_numpy()
xdf, phy_outdf = create_timesteps_pre(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))
print('Target shape (TTF), Y = ', np.shape(ydf_TTF))
print('Target shape (SR), Y = ', np.shape(ydf_SR))
print('Target shape (AE), Y = ', np.shape(ydf_AE))
print('Target shape (A), Y = ', np.shape(Adf))
print('Target shape (Physics_Out), Y = ', np.shape(phy_outdf))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))

# Reshape AE
in_dim = xdf_AE.shape[1]*xdf_AE.shape[2]
xdf_AE = xdf_AE.reshape((xdf_AE.shape[0], in_dim))
print('After reshaping, xdf_AE = ', np.shape(xdf_AE))
# Out:
# Features shape, X =  (9400, 100, 4)
# Target shape (SS), Y =  (9400,)
# Target shape (TTF), Y =  (9400,)
# Target shape (SR), Y =  (9400,)
# Target shape (AE), Y =  (9400,)
# Target shape (A), Y =  (9400,)
# Target shape (Physics_Out), Y =  (9400,)
# After reshaping, X =  (9400, 400)
# After reshaping, xdf_AE =  (9400, 100)

# %%
# Extract SS
ydf_SS = np.concatenate(ydf_SS, axis=0)
print(ydf_SS)
print(ydf_SS.shape)
# Out:
# [[6.08]
#  [6.09]
#  [6.09]
#  ...
#  [5.93]
#  [5.94]
#  [5.94]]
# (1860100, 1)

# %%
# Extract TTF
ydf_TTF = np.concatenate(ydf_TTF, axis=0)
print(ydf_TTF)
print(ydf_TTF.shape)
# Out:
# [[2.07]
#  [1.97]
#  [1.86]
#  ...
#  [6.23]
#  [6.12]
#  [6.12]]
# (1860100, 1)

# %%
# # # # Reshape SS
ydf_SS = ydf_SS[0:1860000]
ydf_SS = np.reshape(ydf_SS, (9300,200))
print(ydf_SS.shape)
# Out:
# (9300, 200)

# %%
# # # # Reshape TTF
ydf_TTF = ydf_TTF[0:1860000]
ydf_TTF = np.reshape(ydf_TTF, (9300,200))
print(ydf_TTF.shape)
# Out:
# (9300, 200)

# %%
# # # Reshape Train
xdf = xdf[0:9300,:]
print(xdf.shape)
# Out:
# (9300, 400)

# %%
# # # Reshape
ydf_SR = ydf_SR[0:9300]
ydf_SR_Org = ydf_SR_Org[0:9300]
ydf_AE = ydf_AE[0:9300]
xdf_AE = xdf_AE[0:9300]
Adf = Adf[0:9300]
phy_outdf = phy_outdf[0:9300]

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.1, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.111, shuffle=False)

# Split into train-val-test (TTF)
x_train, x_test, y_train_TTF, y_test_TTF = train_test_split(xdf, ydf_TTF, test_size=0.1, shuffle=False)
X_train, X_val, Y_train_TTF, Y_val_TTF = train_test_split(x_train, y_train_TTF, test_size=0.111, shuffle=False)

# Split into train-val-test (SR)
x_train, x_test, y_train_SR, y_test_SR = train_test_split(xdf, ydf_SR, test_size=0.1, shuffle=False)
X_train, X_val, Y_train_SR, Y_val_SR = train_test_split(x_train, y_train_SR, test_size=0.111, shuffle=False)

# Split into train-val-test (SR_Org)
x_train, x_test, y_train_SR_Org, y_test_SR_Org = train_test_split(xdf, ydf_SR_Org, test_size=0.1, shuffle=False)
X_train, X_val, Y_train_SR_Org, Y_val_SR_Org = train_test_split(x_train, y_train_SR_Org, test_size=0.111, shuffle=False)

# Split into train-val-test (AE)
x_train, x_test, y_train_AE, y_test_AE = train_test_split(xdf, xdf_AE, test_size=0.1, shuffle=False)
X_train, X_val, Y_train_AE, Y_val_AE = train_test_split(x_train, y_train_AE, test_size=0.111, shuffle=False)

# Split into train-val-test (ae)
x_train, x_test, y_train_ae, y_test_ae = train_test_split(xdf, ydf_AE, test_size=0.1, shuffle=False)
X_train, X_val, Y_train_ae, Y_val_ae = train_test_split(x_train, y_train_ae, test_size=0.111, shuffle=False)

# Split into train-val-test (A)
x_train, x_test, y_train_A, y_test_A = train_test_split(xdf, Adf, test_size=0.1, shuffle=False)
X_train, X_val, Y_train_A, Y_val_A = train_test_split(x_train, y_train_A, test_size=0.111, shuffle=False)

# Split into train-val-test (Physics Out)
x_train, x_test, y_train_Phy, y_test_Phy = train_test_split(xdf, phy_outdf, test_size=0.1, shuffle=False)
X_train, X_val, Y_train_Phy, Y_val_Phy = train_test_split(x_train, y_train_Phy, test_size=0.111, shuffle=False)

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train)[0])
print("Validation samples:", np.shape(X_val)[0])
print("Testing samples:", np.shape(x_test)[0])
# Out:
# Training samples: 7440
# Validation samples: 930
# Testing samples: 930

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler(feature_range=(0, 1))
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))
Y_train_SS = pd.DataFrame(Y_train_SS.values.reshape(7440,200))
Y_val_SS = pd.DataFrame(Y_val_SS.values.reshape(930,200))
y_test_SS = pd.DataFrame(y_test_SS.values.reshape(930,200))

# %%
# Normalize the output: TTF
scaler_ttf = MinMaxScaler(feature_range=(0, 1))
Y_train_TTF = pd.DataFrame(scaler_ttf.fit_transform(Y_train_TTF.reshape(-1, 1)))
Y_val_TTF = pd.DataFrame(scaler_ttf.transform(Y_val_TTF.reshape(-1, 1)))
y_test_TTF = pd.DataFrame(scaler_ttf.transform(y_test_TTF.reshape(-1, 1)))
Y_train_TTF = pd.DataFrame(Y_train_TTF.values.reshape(7440,200))
Y_val_TTF = pd.DataFrame(Y_val_TTF.values.reshape(930,200))
y_test_TTF = pd.DataFrame(y_test_TTF.values.reshape(930,200))

# %%
# # Normalize the output: SR
scaler_sr = MinMaxScaler(feature_range=(-1, 1))
Y_train_SR = pd.DataFrame(scaler_sr.fit_transform(Y_train_SR.reshape(-1, 1)))
Y_val_SR = pd.DataFrame(scaler_sr.transform(Y_val_SR.reshape(-1, 1)))
y_test_SR = pd.DataFrame(scaler_sr.transform(y_test_SR.reshape(-1, 1)))

# %%
# # Normalize the output: SR_Org
scaler_sr_org = MinMaxScaler(feature_range=(0, 1))
Y_train_SR_Org = pd.DataFrame(scaler_sr_org.fit_transform(Y_train_SR_Org.reshape(-1, 1)))
Y_val_SR_Org = pd.DataFrame(scaler_sr_org.transform(Y_val_SR_Org.reshape(-1, 1)))
y_test_SR_Org = pd.DataFrame(scaler_sr_org.transform(y_test_SR_Org.reshape(-1, 1)))

# %%
# Normalize the input: AE
scaler_ae = MinMaxScaler(feature_range=(0, 1))
Y_train_AE = pd.DataFrame(scaler_ae.fit_transform(Y_train_AE))
Y_val_AE = pd.DataFrame(scaler_ae.transform(Y_val_AE))
y_test_AE = pd.DataFrame(scaler_ae.transform(y_test_AE))

# %%
# Normalize Amp
scaler_A = MinMaxScaler(feature_range=(0, 1))
Y_train_A = pd.DataFrame(scaler_A.fit_transform(Y_train_A.reshape(-1, 1)))
Y_val_A = pd.DataFrame(scaler_A.transform(Y_val_A.reshape(-1, 1)))
y_test_A = pd.DataFrame(scaler_A.transform(y_test_A.reshape(-1, 1)))

# %%
# Define Physics 1
# Rate and State Friction
# mu  = mu0 + a*ln(V/V0)+ b*ln(V0*Theta/Dc)
# SS = C1 + C2ln(V/V0) + C3ln(V0*Theta/Dc)

class gradient_1(tf.keras.layers.Layer):
  def __init__(self):
    super(gradient_1,self).__init__()
    self.SS = tf.keras.layers.Dense(1)
    self.SR = tf.keras.layers.Dense(1)
    self.A = tf.keras.layers.Dense(1)
    self.all_scale = tf.keras.layers.Dense(1)
    self.c1 = self.add_weight("c1",trainable=True)
    self.c2 = self.add_weight("c2",trainable=True)
    self.c3 = self.add_weight("c3",trainable=True)
    self.c4 = self.add_weight("c4",trainable=True)
  def call(self, params):
    ss_pred, sr_pred, Amp = params
    ss_pred = self.SS(ss_pred)
    sr_pred = self.SR(sr_pred)
    Amp = self.A(Amp)

    term1 =  ss_pred
    term2 =  sr_pred
    term3 =  Amp - self.c4

    term4 = tf.multiply(self.c2,term2)
    term5 = tf.multiply(self.c3,term3)

    eqn = term1-self.c1-term4-term5
    eqn = self.all_scale(eqn)

    return eqn

# %%
# PINN 2
# AE_Rate = C1 * SR

class gradient_2(tf.keras.layers.Layer):
  def __init__(self):
    super(gradient_2,self).__init__()
    self.SRORG = tf.keras.layers.Dense(1)
    self.AE = tf.keras.layers.Dense(1)
    self.all_scale = tf.keras.layers.Dense(1)
    self.c5 = self.add_weight("c5",trainable=True)

  def call(self, params):
    sr_org_pred, ae = params
    sr_org_pred = self.SRORG(sr_org_pred)
    ae = self.AE(ae)

    term1 = ae
    term2 = self.c5*sr_org_pred
    eqn = term1-term2
    eqn = self.all_scale(eqn)

    return eqn

# %%
# Define PINN
def MLP_Physics():

  # Define inputs
  X_train = layers.Input(shape=(400),name='X_train')
  AE =layers.Input(shape=(100),name='AE')
  Amp =layers.Input(shape=(1),name='Amp')
  ae = layers.Input(shape=(1),name='ae')

  # Prediction: Shear Stress + TTF
  x = layers.Dense(2048,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(1024,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(512,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(256,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(128,kernel_initializer = 'normal', activation="relu")(x)

  ss_pred = layers.Dense(200,kernel_initializer = 'normal',activation="linear")(x)
  ttf_pred = layers.Dense(200,kernel_initializer = 'normal',activation="linear")(x)

  # Prediction: SR
  x = layers.Dense(2048,kernel_initializer = 'normal', activation="relu")(AE)
  x = layers.Dense(1024,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(512, kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(256,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(128,kernel_initializer = 'normal', activation="relu")(x)
  sr_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)
  sr_org_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  grad_out_1 = gradient_1()([ss_pred,sr_pred,Amp])
  grad_out_2 = gradient_2()([sr_org_pred,ae])
  model = keras.Model(inputs=[X_train,AE,Amp,ae],outputs=[ss_pred,ttf_pred])
  return model

# %%
# Model Summary
model=MLP_Physics()
model.compile(loss='mse', optimizer=tf.keras.optimizers.legacy.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  X_train (InputLayer)        [(None, 400)]                0         []
#
#  dense (Dense)               (None, 2048)                 821248    ['X_train[0][0]']
#
#  dense_1 (Dense)             (None, 1024)                 2098176   ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 512)                  524800    ['dense_1[0][0]']
#
#  dense_3 (Dense)             (None, 256)                  131328    ['dense_2[0][0]']
#
#  dense_4 (Dense)             (None, 128)                  32896     ['dense_3[0][0]']
#
#  AE (InputLayer)             [(None, 100)]                0         []
#
#  Amp (InputLayer)            [(None, 1)]                  0         []
#
#  ae (InputLayer)             [(None, 1)]                  0         []
#
#  dense_5 (Dense)             (None, 200)                  25800     ['dense_4[0][0]']
#
#  dense_6 (Dense)             (None, 200)                  25800     ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 3660048 (13.96 MB)
# Trainable params: 3660048 (13.96 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Train The Model
start_time = time.time()
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
callbacks_list = [earlystop]
history = model.fit([X_train,Y_train_AE,Y_train_A,Y_train_ae],[Y_train_SS,Y_train_TTF], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val,Y_val_AE,Y_val_A,Y_val_ae],[Y_val_SS,Y_val_TTF]), verbose=1)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
end_time = time.time()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Train on 7440 samples, validate on 930 samples
# Epoch 1/100
# 7424/7440 [============================>.] - ETA: 0s - loss: 0.0897 - dense_5_loss: 0.0438 - dense_6_loss: 0.0459 - dense_5_mse: 0.0438 - dense_6_mse: 0.0459
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 7440/7440 [==============================] - 15s 2ms/sample - loss: 0.0897 - dense_5_loss: 0.0437 - dense_6_loss: 0.0458 - dense_5_mse: 0.0438 - dense_6_mse: 0.0459 - val_loss: 0.0672 - val_dense_5_loss: 0.0317 - val_dense_6_loss: 0.0353 - val_dense_5_mse: 0.0317 - val_dense_6_mse: 0.0355
# Epoch 2/100
# 7440/7440 [==============================] - 11s 1ms/sample - loss: 0.0492 - dense_5_loss: 0.0226 - dense_6_loss: 0.0266 - dense_5_mse: 0.0226 - dense_6_mse: 0.0266 - val_loss: 0.0562 - val_dense_5_loss: 0.0267 - val_dense_6_loss: 0.0295 - val_dense_5_mse: 0.0267 - val_dense_6_mse: 0.0295
# Epoch 3/100
# 7440/7440 [==============================] - 14s 2ms/sample - loss: 0.0433 - dense_5_loss: 0.0198 - dense_6_loss: 0.0234 - dense_5_mse: 0.0198 - dense_6_mse: 0.0234 - val_loss: 0.0465 - val_dense_5_loss: 0.0216 - val_dense_6_loss: 0.0251 - val_dense_5_mse: 0.0214 - val_dense_6_mse: 0.0251
# Epoch 4/100
# 7440/7440 [==============================] - 15s 2ms/sample - loss: 0.0405 - dense_5_loss: 0.0186 - dense_6_loss: 0.0219 - dense_5_mse: 0.0186 - dense_6_mse: 0.0219 - val_loss: 0.0369 - val_dense_5_loss: 0.0176 - val_dense_6_loss: 0.0195 - val_dense_5_mse: 0.0175 - val_dense_6_mse: 0.0194
# Epoch 5/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0379 - dense_5_loss: 0.0173 - dense_6_loss: 0.0205 - dense_5_mse: 0.0173 - dense_6_mse: 0.0205 - val_loss: 0.0420 - val_dense_5_loss: 0.0191 - val_dense_6_loss: 0.0228 - val_dense_5_mse: 0.0191 - val_dense_6_mse: 0.0229
# Epoch 6/100
# 7440/7440 [==============================] - 11s 1ms/sample - loss: 0.0355 - dense_5_loss: 0.0162 - dense_6_loss: 0.0193 - dense_5_mse: 0.0162 - dense_6_mse: 0.0193 - val_loss: 0.0320 - val_dense_5_loss: 0.0152 - val_dense_6_loss: 0.0168 - val_dense_5_mse: 0.0153 - val_dense_6_mse: 0.0168
# Epoch 7/100
# 7440/7440 [==============================] - 11s 2ms/sample - loss: 0.0336 - dense_5_loss: 0.0153 - dense_6_loss: 0.0182 - dense_5_mse: 0.0153 - dense_6_mse: 0.0183 - val_loss: 0.0321 - val_dense_5_loss: 0.0153 - val_dense_6_loss: 0.0167 - val_dense_5_mse: 0.0153 - val_dense_6_mse: 0.0167
# Epoch 8/100
# 7440/7440 [==============================] - 15s 2ms/sample - loss: 0.0327 - dense_5_loss: 0.0149 - dense_6_loss: 0.0178 - dense_5_mse: 0.0149 - dense_6_mse: 0.0178 - val_loss: 0.0298 - val_dense_5_loss: 0.0142 - val_dense_6_loss: 0.0156 - val_dense_5_mse: 0.0142 - val_dense_6_mse: 0.0156
# Epoch 9/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0321 - dense_5_loss: 0.0147 - dense_6_loss: 0.0174 - dense_5_mse: 0.0147 - dense_6_mse: 0.0174 - val_loss: 0.0296 - val_dense_5_loss: 0.0143 - val_dense_6_loss: 0.0153 - val_dense_5_mse: 0.0142 - val_dense_6_mse: 0.0153
# Epoch 10/100
# 7440/7440 [==============================] - 11s 2ms/sample - loss: 0.0313 - dense_5_loss: 0.0142 - dense_6_loss: 0.0170 - dense_5_mse: 0.0143 - dense_6_mse: 0.0170 - val_loss: 0.0264 - val_dense_5_loss: 0.0123 - val_dense_6_loss: 0.0142 - val_dense_5_mse: 0.0123 - val_dense_6_mse: 0.0141
# Epoch 11/100
# 7440/7440 [==============================] - 10s 1ms/sample - loss: 0.0303 - dense_5_loss: 0.0138 - dense_6_loss: 0.0165 - dense_5_mse: 0.0138 - dense_6_mse: 0.0165 - val_loss: 0.0243 - val_dense_5_loss: 0.0121 - val_dense_6_loss: 0.0121 - val_dense_5_mse: 0.0122 - val_dense_6_mse: 0.0121
# Epoch 12/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0303 - dense_5_loss: 0.0138 - dense_6_loss: 0.0165 - dense_5_mse: 0.0138 - dense_6_mse: 0.0165 - val_loss: 0.0277 - val_dense_5_loss: 0.0132 - val_dense_6_loss: 0.0146 - val_dense_5_mse: 0.0132 - val_dense_6_mse: 0.0145
# Epoch 13/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0292 - dense_5_loss: 0.0133 - dense_6_loss: 0.0159 - dense_5_mse: 0.0133 - dense_6_mse: 0.0159 - val_loss: 0.0248 - val_dense_5_loss: 0.0123 - val_dense_6_loss: 0.0127 - val_dense_5_mse: 0.0123 - val_dense_6_mse: 0.0126
# Epoch 14/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0286 - dense_5_loss: 0.0130 - dense_6_loss: 0.0156 - dense_5_mse: 0.0130 - dense_6_mse: 0.0156 - val_loss: 0.0263 - val_dense_5_loss: 0.0123 - val_dense_6_loss: 0.0139 - val_dense_5_mse: 0.0124 - val_dense_6_mse: 0.0139
# Epoch 15/100
# 7440/7440 [==============================] - 10s 1ms/sample - loss: 0.0279 - dense_5_loss: 0.0127 - dense_6_loss: 0.0152 - dense_5_mse: 0.0127 - dense_6_mse: 0.0152 - val_loss: 0.0243 - val_dense_5_loss: 0.0112 - val_dense_6_loss: 0.0129 - val_dense_5_mse: 0.0113 - val_dense_6_mse: 0.0130
# Epoch 16/100
# 7440/7440 [==============================] - 11s 2ms/sample - loss: 0.0277 - dense_5_loss: 0.0126 - dense_6_loss: 0.0151 - dense_5_mse: 0.0126 - dense_6_mse: 0.0151 - val_loss: 0.0245 - val_dense_5_loss: 0.0118 - val_dense_6_loss: 0.0125 - val_dense_5_mse: 0.0119 - val_dense_6_mse: 0.0126
# Epoch 17/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0274 - dense_5_loss: 0.0124 - dense_6_loss: 0.0150 - dense_5_mse: 0.0124 - dense_6_mse: 0.0150 - val_loss: 0.0215 - val_dense_5_loss: 0.0108 - val_dense_6_loss: 0.0106 - val_dense_5_mse: 0.0109 - val_dense_6_mse: 0.0106
# Epoch 18/100
# 7440/7440 [==============================] - 14s 2ms/sample - loss: 0.0272 - dense_5_loss: 0.0124 - dense_6_loss: 0.0149 - dense_5_mse: 0.0124 - dense_6_mse: 0.0149 - val_loss: 0.0245 - val_dense_5_loss: 0.0120 - val_dense_6_loss: 0.0126 - val_dense_5_mse: 0.0120 - val_dense_6_mse: 0.0125
# Epoch 19/100
# 7440/7440 [==============================] - 11s 1ms/sample - loss: 0.0266 - dense_5_loss: 0.0121 - dense_6_loss: 0.0145 - dense_5_mse: 0.0121 - dense_6_mse: 0.0145 - val_loss: 0.0226 - val_dense_5_loss: 0.0110 - val_dense_6_loss: 0.0115 - val_dense_5_mse: 0.0110 - val_dense_6_mse: 0.0115
# Epoch 20/100
# 7440/7440 [==============================] - 11s 1ms/sample - loss: 0.0261 - dense_5_loss: 0.0118 - dense_6_loss: 0.0143 - dense_5_mse: 0.0118 - dense_6_mse: 0.0143 - val_loss: 0.0237 - val_dense_5_loss: 0.0114 - val_dense_6_loss: 0.0122 - val_dense_5_mse: 0.0114 - val_dense_6_mse: 0.0123
# Epoch 21/100
# 7440/7440 [==============================] - 14s 2ms/sample - loss: 0.0259 - dense_5_loss: 0.0117 - dense_6_loss: 0.0142 - dense_5_mse: 0.0117 - dense_6_mse: 0.0142 - val_loss: 0.0235 - val_dense_5_loss: 0.0111 - val_dense_6_loss: 0.0122 - val_dense_5_mse: 0.0112 - val_dense_6_mse: 0.0123
# Epoch 22/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0255 - dense_5_loss: 0.0115 - dense_6_loss: 0.0139 - dense_5_mse: 0.0115 - dense_6_mse: 0.0139 - val_loss: 0.0219 - val_dense_5_loss: 0.0108 - val_dense_6_loss: 0.0112 - val_dense_5_mse: 0.0108 - val_dense_6_mse: 0.0112
# Epoch 23/100
# 7440/7440 [==============================] - 13s 2ms/sample - loss: 0.0260 - dense_5_loss: 0.0118 - dense_6_loss: 0.0142 - dense_5_mse: 0.0118 - dense_6_mse: 0.0142 - val_loss: 0.0214 - val_dense_5_loss: 0.0101 - val_dense_6_loss: 0.0111 - val_dense_5_mse: 0.0102 - val_dense_6_mse: 0.0112
# Epoch 24/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0253 - dense_5_loss: 0.0115 - dense_6_loss: 0.0139 - dense_5_mse: 0.0114 - dense_6_mse: 0.0139 - val_loss: 0.0202 - val_dense_5_loss: 0.0100 - val_dense_6_loss: 0.0103 - val_dense_5_mse: 0.0100 - val_dense_6_mse: 0.0102
# Epoch 25/100
# 7440/7440 [==============================] - 10s 1ms/sample - loss: 0.0254 - dense_5_loss: 0.0115 - dense_6_loss: 0.0139 - dense_5_mse: 0.0115 - dense_6_mse: 0.0139 - val_loss: 0.0211 - val_dense_5_loss: 0.0103 - val_dense_6_loss: 0.0107 - val_dense_5_mse: 0.0103 - val_dense_6_mse: 0.0107
# Epoch 26/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0247 - dense_5_loss: 0.0111 - dense_6_loss: 0.0135 - dense_5_mse: 0.0111 - dense_6_mse: 0.0135 - val_loss: 0.0195 - val_dense_5_loss: 0.0095 - val_dense_6_loss: 0.0101 - val_dense_5_mse: 0.0094 - val_dense_6_mse: 0.0101
# Epoch 27/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0248 - dense_5_loss: 0.0112 - dense_6_loss: 0.0136 - dense_5_mse: 0.0112 - dense_6_mse: 0.0136 - val_loss: 0.0197 - val_dense_5_loss: 0.0099 - val_dense_6_loss: 0.0099 - val_dense_5_mse: 0.0098 - val_dense_6_mse: 0.0099
# Epoch 28/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0239 - dense_5_loss: 0.0108 - dense_6_loss: 0.0131 - dense_5_mse: 0.0108 - dense_6_mse: 0.0131 - val_loss: 0.0195 - val_dense_5_loss: 0.0097 - val_dense_6_loss: 0.0098 - val_dense_5_mse: 0.0097 - val_dense_6_mse: 0.0098
# Epoch 29/100
# 7440/7440 [==============================] - 10s 1ms/sample - loss: 0.0244 - dense_5_loss: 0.0110 - dense_6_loss: 0.0134 - dense_5_mse: 0.0110 - dense_6_mse: 0.0134 - val_loss: 0.0194 - val_dense_5_loss: 0.0101 - val_dense_6_loss: 0.0093 - val_dense_5_mse: 0.0101 - val_dense_6_mse: 0.0093
# Epoch 30/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0243 - dense_5_loss: 0.0110 - dense_6_loss: 0.0134 - dense_5_mse: 0.0110 - dense_6_mse: 0.0134 - val_loss: 0.0204 - val_dense_5_loss: 0.0101 - val_dense_6_loss: 0.0103 - val_dense_5_mse: 0.0101 - val_dense_6_mse: 0.0103
# Epoch 31/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0240 - dense_5_loss: 0.0108 - dense_6_loss: 0.0132 - dense_5_mse: 0.0108 - dense_6_mse: 0.0132 - val_loss: 0.0189 - val_dense_5_loss: 0.0093 - val_dense_6_loss: 0.0095 - val_dense_5_mse: 0.0094 - val_dense_6_mse: 0.0095
# Epoch 32/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0232 - dense_5_loss: 0.0105 - dense_6_loss: 0.0127 - dense_5_mse: 0.0105 - dense_6_mse: 0.0127 - val_loss: 0.0205 - val_dense_5_loss: 0.0107 - val_dense_6_loss: 0.0099 - val_dense_5_mse: 0.0107 - val_dense_6_mse: 0.0099
# Epoch 33/100
# 7440/7440 [==============================] - 11s 2ms/sample - loss: 0.0236 - dense_5_loss: 0.0106 - dense_6_loss: 0.0129 - dense_5_mse: 0.0106 - dense_6_mse: 0.0129 - val_loss: 0.0195 - val_dense_5_loss: 0.0098 - val_dense_6_loss: 0.0099 - val_dense_5_mse: 0.0097 - val_dense_6_mse: 0.0098
# Epoch 34/100
# 7440/7440 [==============================] - 11s 1ms/sample - loss: 0.0235 - dense_5_loss: 0.0106 - dense_6_loss: 0.0129 - dense_5_mse: 0.0106 - dense_6_mse: 0.0129 - val_loss: 0.0181 - val_dense_5_loss: 0.0090 - val_dense_6_loss: 0.0092 - val_dense_5_mse: 0.0089 - val_dense_6_mse: 0.0092
# Epoch 35/100
# 7440/7440 [==============================] - 14s 2ms/sample - loss: 0.0227 - dense_5_loss: 0.0102 - dense_6_loss: 0.0125 - dense_5_mse: 0.0102 - dense_6_mse: 0.0125 - val_loss: 0.0185 - val_dense_5_loss: 0.0093 - val_dense_6_loss: 0.0092 - val_dense_5_mse: 0.0093 - val_dense_6_mse: 0.0092
# Epoch 36/100
# 7440/7440 [==============================] - 11s 1ms/sample - loss: 0.0224 - dense_5_loss: 0.0100 - dense_6_loss: 0.0123 - dense_5_mse: 0.0100 - dense_6_mse: 0.0123 - val_loss: 0.0176 - val_dense_5_loss: 0.0088 - val_dense_6_loss: 0.0088 - val_dense_5_mse: 0.0088 - val_dense_6_mse: 0.0088
# Epoch 37/100
# 7440/7440 [==============================] - 10s 1ms/sample - loss: 0.0224 - dense_5_loss: 0.0101 - dense_6_loss: 0.0123 - dense_5_mse: 0.0101 - dense_6_mse: 0.0123 - val_loss: 0.0193 - val_dense_5_loss: 0.0095 - val_dense_6_loss: 0.0099 - val_dense_5_mse: 0.0095 - val_dense_6_mse: 0.0098
# Epoch 38/100
# 7440/7440 [==============================] - 11s 2ms/sample - loss: 0.0219 - dense_5_loss: 0.0098 - dense_6_loss: 0.0121 - dense_5_mse: 0.0098 - dense_6_mse: 0.0121 - val_loss: 0.0188 - val_dense_5_loss: 0.0094 - val_dense_6_loss: 0.0092 - val_dense_5_mse: 0.0095 - val_dense_6_mse: 0.0093
# Epoch 39/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0224 - dense_5_loss: 0.0101 - dense_6_loss: 0.0123 - dense_5_mse: 0.0101 - dense_6_mse: 0.0123 - val_loss: 0.0170 - val_dense_5_loss: 0.0084 - val_dense_6_loss: 0.0086 - val_dense_5_mse: 0.0084 - val_dense_6_mse: 0.0087
# Epoch 40/100
# 7440/7440 [==============================] - 11s 2ms/sample - loss: 0.0220 - dense_5_loss: 0.0099 - dense_6_loss: 0.0121 - dense_5_mse: 0.0099 - dense_6_mse: 0.0121 - val_loss: 0.0179 - val_dense_5_loss: 0.0089 - val_dense_6_loss: 0.0091 - val_dense_5_mse: 0.0088 - val_dense_6_mse: 0.0091
# Epoch 41/100
# 7440/7440 [==============================] - 11s 2ms/sample - loss: 0.0217 - dense_5_loss: 0.0097 - dense_6_loss: 0.0120 - dense_5_mse: 0.0097 - dense_6_mse: 0.0120 - val_loss: 0.0183 - val_dense_5_loss: 0.0091 - val_dense_6_loss: 0.0091 - val_dense_5_mse: 0.0091 - val_dense_6_mse: 0.0091
# Epoch 42/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0214 - dense_5_loss: 0.0096 - dense_6_loss: 0.0118 - dense_5_mse: 0.0096 - dense_6_mse: 0.0118 - val_loss: 0.0173 - val_dense_5_loss: 0.0088 - val_dense_6_loss: 0.0085 - val_dense_5_mse: 0.0088 - val_dense_6_mse: 0.0084
# Epoch 43/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0214 - dense_5_loss: 0.0096 - dense_6_loss: 0.0118 - dense_5_mse: 0.0096 - dense_6_mse: 0.0118 - val_loss: 0.0171 - val_dense_5_loss: 0.0086 - val_dense_6_loss: 0.0085 - val_dense_5_mse: 0.0086 - val_dense_6_mse: 0.0085
# Epoch 44/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0214 - dense_5_loss: 0.0096 - dense_6_loss: 0.0118 - dense_5_mse: 0.0096 - dense_6_mse: 0.0118 - val_loss: 0.0189 - val_dense_5_loss: 0.0096 - val_dense_6_loss: 0.0092 - val_dense_5_mse: 0.0096 - val_dense_6_mse: 0.0092
# Epoch 45/100
# 7440/7440 [==============================] - 11s 1ms/sample - loss: 0.0212 - dense_5_loss: 0.0095 - dense_6_loss: 0.0117 - dense_5_mse: 0.0095 - dense_6_mse: 0.0117 - val_loss: 0.0170 - val_dense_5_loss: 0.0085 - val_dense_6_loss: 0.0085 - val_dense_5_mse: 0.0085 - val_dense_6_mse: 0.0085
# Epoch 46/100
# 7440/7440 [==============================] - 13s 2ms/sample - loss: 0.0208 - dense_5_loss: 0.0093 - dense_6_loss: 0.0115 - dense_5_mse: 0.0093 - dense_6_mse: 0.0115 - val_loss: 0.0170 - val_dense_5_loss: 0.0088 - val_dense_6_loss: 0.0083 - val_dense_5_mse: 0.0088 - val_dense_6_mse: 0.0083
# Epoch 47/100
# 7440/7440 [==============================] - 11s 2ms/sample - loss: 0.0211 - dense_5_loss: 0.0094 - dense_6_loss: 0.0116 - dense_5_mse: 0.0094 - dense_6_mse: 0.0116 - val_loss: 0.0168 - val_dense_5_loss: 0.0084 - val_dense_6_loss: 0.0084 - val_dense_5_mse: 0.0084 - val_dense_6_mse: 0.0084
# Epoch 48/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0208 - dense_5_loss: 0.0093 - dense_6_loss: 0.0115 - dense_5_mse: 0.0093 - dense_6_mse: 0.0115 - val_loss: 0.0167 - val_dense_5_loss: 0.0083 - val_dense_6_loss: 0.0082 - val_dense_5_mse: 0.0084 - val_dense_6_mse: 0.0083
# Epoch 49/100
# 7440/7440 [==============================] - 13s 2ms/sample - loss: 0.0209 - dense_5_loss: 0.0094 - dense_6_loss: 0.0115 - dense_5_mse: 0.0094 - dense_6_mse: 0.0115 - val_loss: 0.0159 - val_dense_5_loss: 0.0080 - val_dense_6_loss: 0.0079 - val_dense_5_mse: 0.0081 - val_dense_6_mse: 0.0079
# Epoch 50/100
# 7440/7440 [==============================] - 11s 1ms/sample - loss: 0.0202 - dense_5_loss: 0.0090 - dense_6_loss: 0.0111 - dense_5_mse: 0.0090 - dense_6_mse: 0.0111 - val_loss: 0.0163 - val_dense_5_loss: 0.0082 - val_dense_6_loss: 0.0080 - val_dense_5_mse: 0.0082 - val_dense_6_mse: 0.0081
# Epoch 51/100
# 7440/7440 [==============================] - 11s 1ms/sample - loss: 0.0204 - dense_5_loss: 0.0091 - dense_6_loss: 0.0113 - dense_5_mse: 0.0091 - dense_6_mse: 0.0113 - val_loss: 0.0155 - val_dense_5_loss: 0.0078 - val_dense_6_loss: 0.0077 - val_dense_5_mse: 0.0078 - val_dense_6_mse: 0.0077
# Epoch 52/100
# 7440/7440 [==============================] - 11s 2ms/sample - loss: 0.0203 - dense_5_loss: 0.0091 - dense_6_loss: 0.0112 - dense_5_mse: 0.0091 - dense_6_mse: 0.0112 - val_loss: 0.0168 - val_dense_5_loss: 0.0086 - val_dense_6_loss: 0.0083 - val_dense_5_mse: 0.0086 - val_dense_6_mse: 0.0082
# Epoch 53/100
# 7440/7440 [==============================] - 11s 1ms/sample - loss: 0.0206 - dense_5_loss: 0.0092 - dense_6_loss: 0.0114 - dense_5_mse: 0.0092 - dense_6_mse: 0.0114 - val_loss: 0.0162 - val_dense_5_loss: 0.0084 - val_dense_6_loss: 0.0079 - val_dense_5_mse: 0.0084 - val_dense_6_mse: 0.0079
# Epoch 54/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0201 - dense_5_loss: 0.0090 - dense_6_loss: 0.0111 - dense_5_mse: 0.0090 - dense_6_mse: 0.0111 - val_loss: 0.0167 - val_dense_5_loss: 0.0086 - val_dense_6_loss: 0.0080 - val_dense_5_mse: 0.0086 - val_dense_6_mse: 0.0080
# Epoch 55/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0202 - dense_5_loss: 0.0090 - dense_6_loss: 0.0111 - dense_5_mse: 0.0090 - dense_6_mse: 0.0112 - val_loss: 0.0150 - val_dense_5_loss: 0.0075 - val_dense_6_loss: 0.0076 - val_dense_5_mse: 0.0074 - val_dense_6_mse: 0.0075
# Epoch 56/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0198 - dense_5_loss: 0.0088 - dense_6_loss: 0.0109 - dense_5_mse: 0.0088 - dense_6_mse: 0.0109 - val_loss: 0.0156 - val_dense_5_loss: 0.0078 - val_dense_6_loss: 0.0079 - val_dense_5_mse: 0.0078 - val_dense_6_mse: 0.0078
# Epoch 57/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0198 - dense_5_loss: 0.0089 - dense_6_loss: 0.0110 - dense_5_mse: 0.0089 - dense_6_mse: 0.0110 - val_loss: 0.0162 - val_dense_5_loss: 0.0082 - val_dense_6_loss: 0.0079 - val_dense_5_mse: 0.0082 - val_dense_6_mse: 0.0079
# Epoch 58/100
# 7440/7440 [==============================] - 11s 1ms/sample - loss: 0.0197 - dense_5_loss: 0.0088 - dense_6_loss: 0.0109 - dense_5_mse: 0.0088 - dense_6_mse: 0.0109 - val_loss: 0.0147 - val_dense_5_loss: 0.0074 - val_dense_6_loss: 0.0072 - val_dense_5_mse: 0.0075 - val_dense_6_mse: 0.0073
# Epoch 59/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0196 - dense_5_loss: 0.0087 - dense_6_loss: 0.0108 - dense_5_mse: 0.0087 - dense_6_mse: 0.0108 - val_loss: 0.0158 - val_dense_5_loss: 0.0078 - val_dense_6_loss: 0.0080 - val_dense_5_mse: 0.0078 - val_dense_6_mse: 0.0079
# Epoch 60/100
# 7440/7440 [==============================] - 13s 2ms/sample - loss: 0.0196 - dense_5_loss: 0.0088 - dense_6_loss: 0.0108 - dense_5_mse: 0.0088 - dense_6_mse: 0.0108 - val_loss: 0.0151 - val_dense_5_loss: 0.0077 - val_dense_6_loss: 0.0075 - val_dense_5_mse: 0.0077 - val_dense_6_mse: 0.0074
# Epoch 61/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0190 - dense_5_loss: 0.0085 - dense_6_loss: 0.0105 - dense_5_mse: 0.0085 - dense_6_mse: 0.0105 - val_loss: 0.0146 - val_dense_5_loss: 0.0074 - val_dense_6_loss: 0.0071 - val_dense_5_mse: 0.0074 - val_dense_6_mse: 0.0071
# Epoch 62/100
# 7440/7440 [==============================] - 11s 1ms/sample - loss: 0.0196 - dense_5_loss: 0.0087 - dense_6_loss: 0.0108 - dense_5_mse: 0.0087 - dense_6_mse: 0.0108 - val_loss: 0.0152 - val_dense_5_loss: 0.0079 - val_dense_6_loss: 0.0073 - val_dense_5_mse: 0.0079 - val_dense_6_mse: 0.0073
# Epoch 63/100
# 7440/7440 [==============================] - 13s 2ms/sample - loss: 0.0192 - dense_5_loss: 0.0086 - dense_6_loss: 0.0106 - dense_5_mse: 0.0086 - dense_6_mse: 0.0106 - val_loss: 0.0157 - val_dense_5_loss: 0.0079 - val_dense_6_loss: 0.0077 - val_dense_5_mse: 0.0080 - val_dense_6_mse: 0.0077
# Epoch 64/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0191 - dense_5_loss: 0.0085 - dense_6_loss: 0.0106 - dense_5_mse: 0.0085 - dense_6_mse: 0.0106 - val_loss: 0.0149 - val_dense_5_loss: 0.0075 - val_dense_6_loss: 0.0073 - val_dense_5_mse: 0.0076 - val_dense_6_mse: 0.0073
# Epoch 65/100
# 7440/7440 [==============================] - 14s 2ms/sample - loss: 0.0192 - dense_5_loss: 0.0086 - dense_6_loss: 0.0106 - dense_5_mse: 0.0086 - dense_6_mse: 0.0106 - val_loss: 0.0150 - val_dense_5_loss: 0.0076 - val_dense_6_loss: 0.0074 - val_dense_5_mse: 0.0076 - val_dense_6_mse: 0.0074
# Epoch 66/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0190 - dense_5_loss: 0.0085 - dense_6_loss: 0.0105 - dense_5_mse: 0.0085 - dense_6_mse: 0.0105 - val_loss: 0.0147 - val_dense_5_loss: 0.0074 - val_dense_6_loss: 0.0073 - val_dense_5_mse: 0.0074 - val_dense_6_mse: 0.0073
# Epoch 67/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0188 - dense_5_loss: 0.0084 - dense_6_loss: 0.0104 - dense_5_mse: 0.0084 - dense_6_mse: 0.0104 - val_loss: 0.0156 - val_dense_5_loss: 0.0080 - val_dense_6_loss: 0.0076 - val_dense_5_mse: 0.0080 - val_dense_6_mse: 0.0076
# Epoch 68/100
# 7440/7440 [==============================] - 13s 2ms/sample - loss: 0.0185 - dense_5_loss: 0.0082 - dense_6_loss: 0.0102 - dense_5_mse: 0.0082 - dense_6_mse: 0.0102 - val_loss: 0.0159 - val_dense_5_loss: 0.0081 - val_dense_6_loss: 0.0079 - val_dense_5_mse: 0.0081 - val_dense_6_mse: 0.0078
# Epoch 69/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0188 - dense_5_loss: 0.0084 - dense_6_loss: 0.0104 - dense_5_mse: 0.0084 - dense_6_mse: 0.0104 - val_loss: 0.0151 - val_dense_5_loss: 0.0076 - val_dense_6_loss: 0.0074 - val_dense_5_mse: 0.0077 - val_dense_6_mse: 0.0074
# Epoch 70/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0186 - dense_5_loss: 0.0083 - dense_6_loss: 0.0103 - dense_5_mse: 0.0083 - dense_6_mse: 0.0103 - val_loss: 0.0147 - val_dense_5_loss: 0.0076 - val_dense_6_loss: 0.0072 - val_dense_5_mse: 0.0075 - val_dense_6_mse: 0.0072
# Epoch 71/100
# 7440/7440 [==============================] - 13s 2ms/sample - loss: 0.0193 - dense_5_loss: 0.0086 - dense_6_loss: 0.0107 - dense_5_mse: 0.0086 - dense_6_mse: 0.0107 - val_loss: 0.0152 - val_dense_5_loss: 0.0078 - val_dense_6_loss: 0.0073 - val_dense_5_mse: 0.0079 - val_dense_6_mse: 0.0074
# Epoch 72/100
# 7440/7440 [==============================] - 10s 1ms/sample - loss: 0.0181 - dense_5_loss: 0.0081 - dense_6_loss: 0.0100 - dense_5_mse: 0.0081 - dense_6_mse: 0.0100 - val_loss: 0.0150 - val_dense_5_loss: 0.0077 - val_dense_6_loss: 0.0072 - val_dense_5_mse: 0.0077 - val_dense_6_mse: 0.0073
# Epoch 73/100
# 7440/7440 [==============================] - 11s 2ms/sample - loss: 0.0182 - dense_5_loss: 0.0081 - dense_6_loss: 0.0101 - dense_5_mse: 0.0081 - dense_6_mse: 0.0101 - val_loss: 0.0142 - val_dense_5_loss: 0.0071 - val_dense_6_loss: 0.0069 - val_dense_5_mse: 0.0072 - val_dense_6_mse: 0.0070
# Epoch 74/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0182 - dense_5_loss: 0.0081 - dense_6_loss: 0.0101 - dense_5_mse: 0.0081 - dense_6_mse: 0.0101 - val_loss: 0.0146 - val_dense_5_loss: 0.0073 - val_dense_6_loss: 0.0071 - val_dense_5_mse: 0.0074 - val_dense_6_mse: 0.0072
# Epoch 75/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0181 - dense_5_loss: 0.0080 - dense_6_loss: 0.0100 - dense_5_mse: 0.0080 - dense_6_mse: 0.0100 - val_loss: 0.0142 - val_dense_5_loss: 0.0073 - val_dense_6_loss: 0.0069 - val_dense_5_mse: 0.0073 - val_dense_6_mse: 0.0069
# Epoch 76/100
# 7440/7440 [==============================] - 13s 2ms/sample - loss: 0.0180 - dense_5_loss: 0.0080 - dense_6_loss: 0.0100 - dense_5_mse: 0.0080 - dense_6_mse: 0.0100 - val_loss: 0.0147 - val_dense_5_loss: 0.0077 - val_dense_6_loss: 0.0074 - val_dense_5_mse: 0.0075 - val_dense_6_mse: 0.0072
# Epoch 77/100
# 7440/7440 [==============================] - 11s 1ms/sample - loss: 0.0182 - dense_5_loss: 0.0081 - dense_6_loss: 0.0101 - dense_5_mse: 0.0081 - dense_6_mse: 0.0101 - val_loss: 0.0148 - val_dense_5_loss: 0.0076 - val_dense_6_loss: 0.0071 - val_dense_5_mse: 0.0077 - val_dense_6_mse: 0.0071
# Epoch 78/100
# 7440/7440 [==============================] - 14s 2ms/sample - loss: 0.0184 - dense_5_loss: 0.0082 - dense_6_loss: 0.0102 - dense_5_mse: 0.0082 - dense_6_mse: 0.0102 - val_loss: 0.0145 - val_dense_5_loss: 0.0074 - val_dense_6_loss: 0.0069 - val_dense_5_mse: 0.0075 - val_dense_6_mse: 0.0070
# Epoch 79/100
# 7440/7440 [==============================] - 13s 2ms/sample - loss: 0.0181 - dense_5_loss: 0.0081 - dense_6_loss: 0.0100 - dense_5_mse: 0.0081 - dense_6_mse: 0.0100 - val_loss: 0.0152 - val_dense_5_loss: 0.0075 - val_dense_6_loss: 0.0075 - val_dense_5_mse: 0.0077 - val_dense_6_mse: 0.0076
# Epoch 80/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0177 - dense_5_loss: 0.0079 - dense_6_loss: 0.0099 - dense_5_mse: 0.0079 - dense_6_mse: 0.0098 - val_loss: 0.0143 - val_dense_5_loss: 0.0074 - val_dense_6_loss: 0.0068 - val_dense_5_mse: 0.0074 - val_dense_6_mse: 0.0068
# Epoch 81/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0181 - dense_5_loss: 0.0081 - dense_6_loss: 0.0100 - dense_5_mse: 0.0081 - dense_6_mse: 0.0100 - val_loss: 0.0150 - val_dense_5_loss: 0.0079 - val_dense_6_loss: 0.0073 - val_dense_5_mse: 0.0078 - val_dense_6_mse: 0.0072
# Epoch 82/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0177 - dense_5_loss: 0.0079 - dense_6_loss: 0.0098 - dense_5_mse: 0.0079 - dense_6_mse: 0.0098 - val_loss: 0.0147 - val_dense_5_loss: 0.0074 - val_dense_6_loss: 0.0072 - val_dense_5_mse: 0.0075 - val_dense_6_mse: 0.0072
# Epoch 83/100
# 7440/7440 [==============================] - 11s 2ms/sample - loss: 0.0179 - dense_5_loss: 0.0080 - dense_6_loss: 0.0099 - dense_5_mse: 0.0080 - dense_6_mse: 0.0099 - val_loss: 0.0149 - val_dense_5_loss: 0.0076 - val_dense_6_loss: 0.0073 - val_dense_5_mse: 0.0076 - val_dense_6_mse: 0.0073
# Epoch 84/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0180 - dense_5_loss: 0.0081 - dense_6_loss: 0.0100 - dense_5_mse: 0.0080 - dense_6_mse: 0.0100 - val_loss: 0.0154 - val_dense_5_loss: 0.0078 - val_dense_6_loss: 0.0077 - val_dense_5_mse: 0.0078 - val_dense_6_mse: 0.0076
# Epoch 85/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0172 - dense_5_loss: 0.0077 - dense_6_loss: 0.0096 - dense_5_mse: 0.0077 - dense_6_mse: 0.0096 - val_loss: 0.0144 - val_dense_5_loss: 0.0076 - val_dense_6_loss: 0.0070 - val_dense_5_mse: 0.0075 - val_dense_6_mse: 0.0069
# Epoch 86/100
# 7440/7440 [==============================] - 13s 2ms/sample - loss: 0.0176 - dense_5_loss: 0.0078 - dense_6_loss: 0.0097 - dense_5_mse: 0.0078 - dense_6_mse: 0.0097 - val_loss: 0.0143 - val_dense_5_loss: 0.0075 - val_dense_6_loss: 0.0071 - val_dense_5_mse: 0.0073 - val_dense_6_mse: 0.0070
# Epoch 87/100
# 7440/7440 [==============================] - 11s 2ms/sample - loss: 0.0172 - dense_5_loss: 0.0076 - dense_6_loss: 0.0095 - dense_5_mse: 0.0076 - dense_6_mse: 0.0095 - val_loss: 0.0141 - val_dense_5_loss: 0.0074 - val_dense_6_loss: 0.0067 - val_dense_5_mse: 0.0074 - val_dense_6_mse: 0.0068
# Epoch 88/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0170 - dense_5_loss: 0.0075 - dense_6_loss: 0.0094 - dense_5_mse: 0.0075 - dense_6_mse: 0.0094 - val_loss: 0.0144 - val_dense_5_loss: 0.0073 - val_dense_6_loss: 0.0073 - val_dense_5_mse: 0.0072 - val_dense_6_mse: 0.0072
# Epoch 89/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0176 - dense_5_loss: 0.0078 - dense_6_loss: 0.0097 - dense_5_mse: 0.0078 - dense_6_mse: 0.0097 - val_loss: 0.0144 - val_dense_5_loss: 0.0074 - val_dense_6_loss: 0.0071 - val_dense_5_mse: 0.0074 - val_dense_6_mse: 0.0070
# Epoch 90/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0174 - dense_5_loss: 0.0078 - dense_6_loss: 0.0097 - dense_5_mse: 0.0078 - dense_6_mse: 0.0097 - val_loss: 0.0149 - val_dense_5_loss: 0.0076 - val_dense_6_loss: 0.0072 - val_dense_5_mse: 0.0077 - val_dense_6_mse: 0.0072
# Epoch 91/100
# 7440/7440 [==============================] - 13s 2ms/sample - loss: 0.0170 - dense_5_loss: 0.0076 - dense_6_loss: 0.0094 - dense_5_mse: 0.0076 - dense_6_mse: 0.0094 - val_loss: 0.0146 - val_dense_5_loss: 0.0076 - val_dense_6_loss: 0.0070 - val_dense_5_mse: 0.0076 - val_dense_6_mse: 0.0070
# Epoch 92/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0171 - dense_5_loss: 0.0076 - dense_6_loss: 0.0095 - dense_5_mse: 0.0076 - dense_6_mse: 0.0095 - val_loss: 0.0145 - val_dense_5_loss: 0.0074 - val_dense_6_loss: 0.0070 - val_dense_5_mse: 0.0074 - val_dense_6_mse: 0.0070
# Epoch 93/100
# 7440/7440 [==============================] - 11s 1ms/sample - loss: 0.0168 - dense_5_loss: 0.0075 - dense_6_loss: 0.0093 - dense_5_mse: 0.0075 - dense_6_mse: 0.0093 - val_loss: 0.0145 - val_dense_5_loss: 0.0074 - val_dense_6_loss: 0.0071 - val_dense_5_mse: 0.0074 - val_dense_6_mse: 0.0071
# Epoch 94/100
# 7440/7440 [==============================] - 11s 2ms/sample - loss: 0.0175 - dense_5_loss: 0.0078 - dense_6_loss: 0.0097 - dense_5_mse: 0.0078 - dense_6_mse: 0.0097 - val_loss: 0.0151 - val_dense_5_loss: 0.0077 - val_dense_6_loss: 0.0074 - val_dense_5_mse: 0.0077 - val_dense_6_mse: 0.0074
# Epoch 95/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0165 - dense_5_loss: 0.0073 - dense_6_loss: 0.0092 - dense_5_mse: 0.0073 - dense_6_mse: 0.0092 - val_loss: 0.0148 - val_dense_5_loss: 0.0076 - val_dense_6_loss: 0.0075 - val_dense_5_mse: 0.0075 - val_dense_6_mse: 0.0073
# Epoch 96/100
# 7440/7440 [==============================] - 11s 2ms/sample - loss: 0.0168 - dense_5_loss: 0.0075 - dense_6_loss: 0.0093 - dense_5_mse: 0.0075 - dense_6_mse: 0.0093 - val_loss: 0.0144 - val_dense_5_loss: 0.0073 - val_dense_6_loss: 0.0069 - val_dense_5_mse: 0.0074 - val_dense_6_mse: 0.0070
# Epoch 97/100
# 7440/7440 [==============================] - 11s 1ms/sample - loss: 0.0169 - dense_5_loss: 0.0075 - dense_6_loss: 0.0094 - dense_5_mse: 0.0075 - dense_6_mse: 0.0094 - val_loss: 0.0144 - val_dense_5_loss: 0.0074 - val_dense_6_loss: 0.0070 - val_dense_5_mse: 0.0074 - val_dense_6_mse: 0.0070
# Epoch 98/100
# 7440/7440 [==============================] - 11s 2ms/sample - loss: 0.0165 - dense_5_loss: 0.0073 - dense_6_loss: 0.0092 - dense_5_mse: 0.0073 - dense_6_mse: 0.0091 - val_loss: 0.0140 - val_dense_5_loss: 0.0071 - val_dense_6_loss: 0.0068 - val_dense_5_mse: 0.0072 - val_dense_6_mse: 0.0068
# Epoch 99/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0166 - dense_5_loss: 0.0074 - dense_6_loss: 0.0092 - dense_5_mse: 0.0074 - dense_6_mse: 0.0092 - val_loss: 0.0141 - val_dense_5_loss: 0.0072 - val_dense_6_loss: 0.0070 - val_dense_5_mse: 0.0071 - val_dense_6_mse: 0.0070
# Epoch 100/100
# 7440/7440 [==============================] - 12s 2ms/sample - loss: 0.0166 - dense_5_loss: 0.0074 - dense_6_loss: 0.0092 - dense_5_mse: 0.0074 - dense_6_mse: 0.0092 - val_loss: 0.0147 - val_dense_5_loss: 0.0075 - val_dense_6_loss: 0.0071 - val_dense_5_mse: 0.0075 - val_dense_6_mse: 0.0072
# ---Training time: 1194.74427629 seconds ---

# %%
# Predictions: Training
y_predtrain = model.predict([X_train,Y_train_AE,Y_train_A,Y_train_ae])
y_predtrain_SS = np.array(y_predtrain)[0,]
y_predtrain_TTF =np.array(y_predtrain)[1,]

# Predictions: Validation
y_predval = model.predict([X_val,Y_val_AE,Y_val_A,Y_val_ae])
y_predval_SS = np.array(y_predval)[0,]
y_predval_TTF =np.array(y_predval)[1,]

# Predictions: Testing
y_predtest = model.predict([x_test,y_test_AE,y_test_A,y_test_ae])
y_predtest_SS = np.array(y_predtest)[0,]
y_predtest_TTF =np.array(y_predtest)[1,]
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
# Inverse scaling: SS
Y_train_SS = scaler_ss.inverse_transform(Y_train_SS)
Y_val_SS = scaler_ss.inverse_transform(Y_val_SS)
y_test_SS = scaler_ss.inverse_transform(y_test_SS)
y_predtrain_SS = scaler_ss.inverse_transform(y_predtrain_SS)
y_predval_SS = scaler_ss.inverse_transform(y_predval_SS)
y_predtest_SS = scaler_ss.inverse_transform(y_predtest_SS)

# %%
# Inverse scaling: TTF
Y_train_TTF = scaler_ttf.inverse_transform(Y_train_TTF)
Y_val_TTF = scaler_ttf.inverse_transform(Y_val_TTF)
y_test_TTF = scaler_ttf.inverse_transform(y_test_TTF)
y_predtrain_TTF = scaler_ttf.inverse_transform(y_predtrain_TTF)
y_predval_TTF = scaler_ttf.inverse_transform(y_predval_TTF)
y_predtest_TTF = scaler_ttf.inverse_transform(y_predtest_TTF)

# %%
# Model Performance: Training
train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))
train_r2_TTF = r2_score(Y_train_TTF, y_predtrain_TTF)
train_rmse_TTF = np.sqrt(mean_squared_error(Y_train_TTF, y_predtrain_TTF))

# Model Performance: Validation
val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))
val_r2_TTF = r2_score(Y_val_TTF, y_predval_TTF)
val_rmse_TTF = np.sqrt(mean_squared_error(Y_val_TTF, y_predval_TTF))

# Model Performance: Testing
test_r2_SS = r2_score(y_test_SS, y_predtest_SS)
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))
test_r2_TTF = r2_score(y_test_TTF, y_predtest_TTF)
test_rmse_TTF = np.sqrt(mean_squared_error(y_test_TTF, y_predtest_TTF))

# %%
# Print R2 Results
print("R2 scores: Train (SS) - %0.5f, Train (TTF) - %0.5f" %(train_r2_SS, train_r2_TTF))
print("R2 scores: Val (SS) - %0.5f, Val (TTF) - %0.5f" %(val_r2_SS,val_r2_TTF))
print("R2 scores: Test (SS) - %0.5f, Test (TTF) - %0.5f" %(test_r2_SS,test_r2_TTF))
# Out:
# R2 scores: Train (SS) - 0.88653, Train (TTF) - 0.87869
# R2 scores: Val (SS) - 0.90006, Val (TTF) - 0.91534
# R2 scores: Test (SS) - 0.51425, Test (TTF) - 0.53891
