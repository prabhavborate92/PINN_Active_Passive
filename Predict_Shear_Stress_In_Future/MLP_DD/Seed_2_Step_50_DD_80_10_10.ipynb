# %%
# Load Libraries
import pandas as pd
import numpy as np
import os
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt

# %%
# Seed
np.random.seed(10)
tf.random.set_seed(10)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Change the current working directory
os.chdir('/content/drive/My Drive/Colab Notebooks/PINN_Active_Passive_Paper/p5763')
# Print the current working directory
print("Current working directory: {0}".format(os.getcwd()))
# Out:
# Current working directory: /content/drive/My Drive/Colab Notebooks/PINN_Active_Passive_Paper/p5763

# %%
# Function: Create Data History
def create_timesteps(data, data1, n_steps, step):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :], data1[(end_ix):(end_ix + step),:]
		x.append(x1)
		y.append(y1)
	return np.array(x,dtype=object), np.array(y,dtype=object)

# %%
# Load Features
os.chdir('/content/drive/My Drive/Colab Notebooks/PINN_Active_Passive_Paper/p5763/Data')
Data1 = loadmat('p5763_Set1_Inputs.mat')
Data2 = loadmat('p5763_Set1_Outputs.mat')
Features = pd.DataFrame({'Time':Data1['Time'].ravel().round(2),'K':Data1['K'].ravel().round(2),'V':Data1['V'].ravel().round(2),'AE':Data1['AE'].ravel().round(2),
                         'ln_V0_Theta':Data1['ln_V0_Theta'].ravel().round(2)})
Output = pd.DataFrame({'Time':Data2['Time'].ravel().round(2),'SS':Data2['SS'].ravel().round(2),'ln_V_V0':Data2['ln_V_V0'].ravel().round(2),'TTF':Data2['TTF'].ravel().round(2),
                       'physics_out':Data2['physics_out'].ravel().round(2), 'SR':Data2['SR'].ravel().round(2)})
df = Features.merge(Output, on = 'Time')
df = df[['K','V','AE','ln_V0_Theta','SS','TTF','Time']]
df_AE = df[['AE','AE']]
df_SS = df[['K','V','AE','ln_V0_Theta']]
df_SS_1 = df[['SS']]
df_TTF = df[['K','V','AE','ln_V0_Theta']]
df_TTF_1 = df[['TTF']]
xdf = df[['K','V','AE','ln_V0_Theta']]
ydf = df[['SS','TTF']]
print("Input Data:\n", xdf)
print("Target Data:\n",ydf)
print("SS:\n",df_SS_1)
print("TTF:\n",df_TTF_1)
# Out:
# Input Data:
#              K      V    AE  ln_V0_Theta
# 0     5957.24  17.78  2.00         9.95
# 1     5960.89  17.79  2.00         9.94
# 2     6214.84  17.81  2.00         9.94
# 3     4543.97  17.74  2.00         9.95
# 4     4554.15  17.76  1.67         9.94
# ...       ...    ...   ...          ...
# 9495  1033.99  16.82  2.00         9.75
# 9496  1032.72  16.81  2.00         9.77
# 9497  1032.13  16.81  1.67         9.76
# 9498  1032.36  16.81  1.67         9.74
# 9499  1114.37  16.83  1.50         9.74
#
# [9500 rows x 4 columns]
# Target Data:
#          SS   TTF
# 0     6.05  0.00
# 1     6.06  0.00
# 2     6.06  0.00
# 3     6.07  0.00
# 4     6.07  0.00
# ...    ...   ...
# 9495  5.92  6.55
# 9496  5.92  6.45
# 9497  5.93  6.34
# 9498  5.93  6.23
# 9499  5.94  6.12
#
# [9500 rows x 2 columns]
# SS:
#          SS
# 0     6.05
# 1     6.06
# 2     6.06
# 3     6.07
# 4     6.07
# ...    ...
# 9495  5.92
# 9496  5.92
# 9497  5.93
# 9498  5.93
# 9499  5.94
#
# [9500 rows x 1 columns]
# TTF:
#         TTF
# 0     0.00
# 1     0.00
# 2     0.00
# 3     0.00
# 4     0.00
# ...    ...
# 9495  6.55
# 9496  6.45
# 9497  6.34
# 9498  6.23
# 9499  6.12
#
# [9500 rows x 1 columns]

# %%
n_steps = 100 # History for input features
step = 50  # Steps to predict in future

# Preprocessing (SS)
arr = df_SS.to_numpy()
arr1 = df_SS_1.to_numpy()
arr1.transpose()
xdf, ydf_SS = create_timesteps(arr, arr1, n_steps, step)

# Preprocessing (TTF)
arr = df_TTF.to_numpy()
arr1 = df_TTF_1.to_numpy()
arr1.transpose()
xdf, ydf_TTF = create_timesteps(arr, arr1, n_steps, step)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))
print('Target shape (TTF), Y = ', np.shape(ydf_TTF))

# # Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))
# Out:
# Features shape, X =  (9400, 100, 4)
# Target shape (SS), Y =  (9400,)
# Target shape (TTF), Y =  (9400,)
# After reshaping, X =  (9400, 400)

# %%
# Extract SS
ydf_SS = np.concatenate(ydf_SS, axis=0)
print(ydf_SS)
print(ydf_SS.shape)
# Out:
# [[6.08]
#  [6.09]
#  [6.09]
#  ...
#  [5.93]
#  [5.94]
#  [5.94]]
# (468775, 1)

# %%
# Extract TTF
ydf_TTF = np.concatenate(ydf_TTF, axis=0)
print(ydf_TTF)
print(ydf_TTF.shape)
# Out:
# [[2.07]
#  [1.97]
#  [1.86]
#  ...
#  [6.23]
#  [6.12]
#  [6.12]]
# (468775, 1)

# %%
# # Reshape SS
ydf_SS = ydf_SS[0:468750]
ydf_SS = np.reshape(ydf_SS, (9375,50))
print(ydf_SS.shape)
# Out:
# (9375, 50)

# %%
# # Reshape TTF
ydf_TTF = ydf_TTF[0:468750]
ydf_TTF = np.reshape(ydf_TTF, (9375,50))
print(ydf_TTF.shape)
# Out:
# (9375, 50)

# %%
# # Reshape Train
xdf = xdf[0:9375,:]
print(xdf.shape)
# Out:
# (9375, 400)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.1, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.111, shuffle=False)

# Split into train-val-test (TTF)
x_train, x_test, y_train_TTF, y_test_TTF = train_test_split(xdf, ydf_TTF, test_size=0.1, shuffle=False)
X_train, X_val, Y_train_TTF, Y_val_TTF = train_test_split(x_train, y_train_TTF, test_size=0.111, shuffle=False)

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train))
print("Validation samples:", np.shape(X_val))
print("Testing samples:", np.shape(x_test))
# Out:
# Training samples: (7500, 400)
# Validation samples: (937, 400)
# Testing samples: (938, 400)

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler(feature_range=(0, 1))
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS).reshape(-1, 1))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS).reshape(-1, 1))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS).reshape(-1, 1))
Y_train_SS = pd.DataFrame(Y_train_SS.values.reshape(7500,50))
Y_val_SS = pd.DataFrame(Y_val_SS.values.reshape(937,50))
y_test_SS = pd.DataFrame(y_test_SS.values.reshape(938,50))

# %%
# Normalize the output: TTF
scaler_ttf = MinMaxScaler(feature_range=(0, 1))
Y_train_TTF = pd.DataFrame(scaler_ttf.fit_transform(Y_train_TTF.reshape(-1, 1)))
Y_val_TTF = pd.DataFrame(scaler_ttf.transform(Y_val_TTF.reshape(-1, 1)))
y_test_TTF = pd.DataFrame(scaler_ttf.transform(y_test_TTF.reshape(-1, 1)))
Y_train_TTF = pd.DataFrame(Y_train_TTF.values.reshape(7500,50))
Y_val_TTF = pd.DataFrame(Y_val_TTF.values.reshape(937,50))
y_test_TTF = pd.DataFrame(y_test_TTF.values.reshape(938,50))

# %%
# Define DD Model
def MLP_Physics():

  # Define inputs
  X_train = layers.Input(shape=(400),name='X_train')

  # Prediction: Shear Stress + TTF
  x = layers.Dense(2048,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(1024,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(512,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(256,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(128,kernel_initializer = 'normal', activation="relu")(x)
  ss_pred = layers.Dense(50,kernel_initializer = 'normal',activation="linear")(x)
  ttf_pred = layers.Dense(50,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train],outputs=[ss_pred,ttf_pred])
  return model

# %%
# Model Summary
model=MLP_Physics()
model.compile(loss='mse', optimizer=tf.keras.optimizers.legacy.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  X_train (InputLayer)        [(None, 400)]                0         []
#
#  dense (Dense)               (None, 2048)                 821248    ['X_train[0][0]']
#
#  dense_1 (Dense)             (None, 1024)                 2098176   ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 512)                  524800    ['dense_1[0][0]']
#
#  dense_3 (Dense)             (None, 256)                  131328    ['dense_2[0][0]']
#
#  dense_4 (Dense)             (None, 128)                  32896     ['dense_3[0][0]']
#
#  dense_5 (Dense)             (None, 50)                   6450      ['dense_4[0][0]']
#
#  dense_6 (Dense)             (None, 50)                   6450      ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 3621348 (13.81 MB)
# Trainable params: 3621348 (13.81 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Train The Model
start_time = time.time()
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
callbacks_list = [earlystop]
history = model.fit([X_train],[Y_train_SS,Y_train_TTF], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val],[Y_val_SS,Y_val_TTF]), verbose=1)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
end_time = time.time()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Train on 7500 samples, validate on 937 samples
# Epoch 1/100
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0580 - dense_5_loss: 0.0275 - dense_6_loss: 0.0304 - dense_5_mse: 0.0275 - dense_6_mse: 0.0305
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 7500/7500 [==============================] - 10s 1ms/sample - loss: 0.0580 - dense_5_loss: 0.0275 - dense_6_loss: 0.0304 - dense_5_mse: 0.0275 - dense_6_mse: 0.0305 - val_loss: 0.0346 - val_dense_5_loss: 0.0163 - val_dense_6_loss: 0.0187 - val_dense_5_mse: 0.0161 - val_dense_6_mse: 0.0185
# Epoch 2/100
# 7500/7500 [==============================] - 8s 1ms/sample - loss: 0.0289 - dense_5_loss: 0.0130 - dense_6_loss: 0.0159 - dense_5_mse: 0.0130 - dense_6_mse: 0.0159 - val_loss: 0.0344 - val_dense_5_loss: 0.0173 - val_dense_6_loss: 0.0176 - val_dense_5_mse: 0.0170 - val_dense_6_mse: 0.0174
# Epoch 3/100
# 7500/7500 [==============================] - 9s 1ms/sample - loss: 0.0270 - dense_5_loss: 0.0123 - dense_6_loss: 0.0147 - dense_5_mse: 0.0123 - dense_6_mse: 0.0147 - val_loss: 0.0258 - val_dense_5_loss: 0.0125 - val_dense_6_loss: 0.0136 - val_dense_5_mse: 0.0124 - val_dense_6_mse: 0.0135
# Epoch 4/100
# 7500/7500 [==============================] - 9s 1ms/sample - loss: 0.0255 - dense_5_loss: 0.0115 - dense_6_loss: 0.0140 - dense_5_mse: 0.0115 - dense_6_mse: 0.0140 - val_loss: 0.0243 - val_dense_5_loss: 0.0109 - val_dense_6_loss: 0.0137 - val_dense_5_mse: 0.0107 - val_dense_6_mse: 0.0135
# Epoch 5/100
# 7500/7500 [==============================] - 8s 1ms/sample - loss: 0.0246 - dense_5_loss: 0.0111 - dense_6_loss: 0.0135 - dense_5_mse: 0.0111 - dense_6_mse: 0.0135 - val_loss: 0.0260 - val_dense_5_loss: 0.0108 - val_dense_6_loss: 0.0150 - val_dense_5_mse: 0.0109 - val_dense_6_mse: 0.0151
# Epoch 6/100
# 7500/7500 [==============================] - 9s 1ms/sample - loss: 0.0230 - dense_5_loss: 0.0103 - dense_6_loss: 0.0127 - dense_5_mse: 0.0103 - dense_6_mse: 0.0127 - val_loss: 0.0222 - val_dense_5_loss: 0.0108 - val_dense_6_loss: 0.0116 - val_dense_5_mse: 0.0107 - val_dense_6_mse: 0.0115
# Epoch 7/100
# 7500/7500 [==============================] - 9s 1ms/sample - loss: 0.0223 - dense_5_loss: 0.0099 - dense_6_loss: 0.0124 - dense_5_mse: 0.0099 - dense_6_mse: 0.0124 - val_loss: 0.0221 - val_dense_5_loss: 0.0097 - val_dense_6_loss: 0.0122 - val_dense_5_mse: 0.0098 - val_dense_6_mse: 0.0123
# Epoch 8/100
# 7500/7500 [==============================] - 9s 1ms/sample - loss: 0.0213 - dense_5_loss: 0.0095 - dense_6_loss: 0.0118 - dense_5_mse: 0.0095 - dense_6_mse: 0.0118 - val_loss: 0.0182 - val_dense_5_loss: 0.0085 - val_dense_6_loss: 0.0097 - val_dense_5_mse: 0.0085 - val_dense_6_mse: 0.0097
# Epoch 9/100
# 7500/7500 [==============================] - 11s 1ms/sample - loss: 0.0209 - dense_5_loss: 0.0093 - dense_6_loss: 0.0116 - dense_5_mse: 0.0093 - dense_6_mse: 0.0116 - val_loss: 0.0194 - val_dense_5_loss: 0.0100 - val_dense_6_loss: 0.0096 - val_dense_5_mse: 0.0099 - val_dense_6_mse: 0.0095
# Epoch 10/100
# 7500/7500 [==============================] - 10s 1ms/sample - loss: 0.
100
# 7500/7500 [==============================] - 8s 1ms/sample - loss: 0.0143 - dense_5_loss: 0.0062 - dense_6_loss: 0.0081 - dense_5_mse: 0.0062 - dense_6_mse: 0.0081 - val_loss: 0.0117 - val_dense_5_loss: 0.0060 - val_dense_6_loss: 0.0056 - val_dense_5_mse: 0.0060 - val_dense_6_mse: 0.0057
# Epoch 42/100
# 7500/7500 [==============================] - 9s 1ms/sample - loss: 0.0144 - dense_5_loss: 0.0062 - dense_6_loss: 0.0082 - dense_5_mse: 0.0062 - dense_6_mse: 0.0082 - val_loss: 0.0100 - val_dense_5_loss: 0.0053 - val_dense_6_loss: 0.0047 - val_dense_5_mse: 0.0053 - val_dense_6_mse: 0.0047
# Epoch 43/100
# 7500/7500 [==============================] - 10s 1ms/sample - loss: 0.0142 - dense_5_loss: 0.0061 - dense_6_loss: 0.0081 - dense_5_mse: 0.0061 - dense_6_mse: 0.0081 - val_loss: 0.0135 - val_dense_5_loss: 0.0071 - val_dense_6_loss: 0.0063 - val_dense_5_mse: 0.0071 - val_dense_6_mse: 0.0063
# Epoch 44/100
# 7500/7500 [==============================] - 8s 1ms/sample - loss: 0.0138 - dense_5_loss: 0.0060 - dense_6_loss: 0.0078 - dense_5_mse: 0.0060 - dense_6_mse: 0.0079 - val_loss: 0.0117 - val_dense_5_loss: 0.0063 - val_dense_6_loss: 0.0054 - val_dense_5_mse: 0.0063 - val_dense_6_mse: 0.0054
# Epoch 45/100
# 7500/7500 [==============================] - 9s 1ms/sample - loss: 0.0140 - dense_5_loss: 0.0060 - dense_6_loss: 0.0079 - dense_5_mse: 0.0060 - dense_6_mse: 0.0079 - val_loss: 0.0107 - val_dense_5_loss: 0.0056 - val_dense_6_loss: 0.0052 - val_dense_5_mse: 0.0056 - val_dense_6_mse: 0.0052
# Epoch 46/100
# 7500/7500 [==============================] - 10s 1ms/sample - loss: 0.0142 - dense_5_loss: 0.0062 - dense_6_loss: 0.0081 - dense_5_mse: 0.0062 - dense_6_mse: 0.0081 - val_loss: 0.0113 - val_dense_5_loss: 0.0059 - val_dense_6_loss: 0.0053 - val_dense_5_mse: 0.0060 - val_dense_6_mse: 0.0053
# Epoch 47/100
# 7500/7500 [==============================] - 8s 1ms/sample - loss: 0.0138 - dense_5_loss: 0.0060 - dense_6_loss: 0.0078 - dense_5_mse: 0.0060 - dense_6_mse: 0.0079 - val_loss: 0.0103 - val_dense_5_loss: 0.0055 - val_dense_6_loss: 0.0047 - val_dense_5_mse: 0.0055 - val_dense_6_mse: 0.0048
# Epoch 48/100
# 7500/7500 [==============================] - 9s 1ms/sample - loss: 0.0138 - dense_5_loss: 0.0060 - dense_6_loss: 0.0079 - dense_5_mse: 0.0060 - dense_6_mse: 0.0079 - val_loss: 0.0119 - val_dense_5_loss: 0.0061 - val_dense_6_loss: 0.0058 - val_dense_5_mse: 0.0061 - val_dense_6_mse: 0.0058
# Epoch 49/100
# 7500/7500 [==============================] - 9s 1ms/sample - loss: 0.0136 - dense_5_loss: 0.0059 - dense_6_loss: 0.0078 - dense_5_mse: 0.0059 - dense_6_mse: 0.0078 - val_loss: 0.0114 - val_dense_5_loss: 0.0059 - val_dense_6_loss: 0.0055 - val_dense_5_mse: 0.0059 - val_dense_6_mse: 0.0055
# Epoch 50/100
# 7500/7500 [==============================] - 9s 1ms/sample - loss: 0.0135 - dense_5_loss: 0.0058 - dense_6_loss: 0.0077 - dense_5_mse: 0.0058 - dense_6_mse: 0.0077 - val_loss: 0.0115 - val_dense_5_loss: 0.0058 - val_dense_6_loss: 0.0058 - val_dense_5_mse: 0.0058 - val_dense_6_mse: 0.0058
# Epoch 51/100
# 7500/7500 [==============================] - 10s 1ms/sample - loss: 0.0134 - dense_5_loss: 0.0058 - dense_6_loss: 0.0076 - dense_5_mse: 0.0058 - dense_6_mse: 0.0076 - val_loss: 0.0118 - val_dense_5_loss: 0.0062 - val_dense_6_loss: 0.0056 - val_dense_5_mse: 0.0062 - val_dense_6_mse: 0.0056
# Epoch 52/100
# 7500/7500 [==============================] - 9s 1ms/sample - loss: 0.0136 - dense_5_loss: 0.0059 - dense_6_loss: 0.0077 - dense_5_mse: 0.0059 - dense_6_mse: 0.0077 - val_loss: 0.0122 - val_dense_5_loss: 0.0064 - val_dense_6_loss: 0.0060 - val_dense_5_mse: 0.0063 - val_dense_6_mse: 0.0059
# Epoch 53/100
# 7500/7500 [==============================] - 9s 1ms/sample - loss: 0.0134 - dense_5_loss: 0.0058 - dense_6_loss: 0.0076 - dense_5_mse: 0.0058 - dense_6_mse: 0.0076 - val_loss: 0.0109 - val_dense_5_loss: 0.0057 - val_dense_6_loss: 0.0051 - val_dense_5_mse: 0.0058 - val_dense_6_mse: 0.0052
# Epoch 54/100
# 7500/7500 [==============================] - 10s 1ms/sample - loss: 0.0131 - dense_5_loss: 0.0056 - dense_6_loss: 0.0075 - dense_5_mse: 0.0056 - dense_6_mse: 0.0075 - val_loss: 0.0103 - val_dense_5_loss: 0.0055 - val_dense_6_loss: 0.0048 - val_dense_5_mse: 0.0055 - val_dense_6_mse: 0.0048
# Epoch 55/100
# 7500/7500 [==============================] - 8s 1ms/sample - loss: 0.0131 - dense_5_loss: 0.0056 - dense_6_loss: 0.0075 - dense_5_mse: 0.0056 - dense_6_mse: 0.0075 - val_loss: 0.0114 - val_dense_5_loss: 0.0061 - val_dense_6_loss: 0.0056 - val_dense_5_mse: 0.0060 - val_dense_6_mse: 0.0055
# Epoch 56/100
# 7500/7500 [==============================] - 10s 1ms/sample - loss: 0.0133 - dense_5_loss: 0.0057 - dense_6_loss: 0.0075 - dense_5_mse: 0.0057 - dense_6_mse: 0.0076 - val_loss: 0.0120 - val_dense_5_loss: 0.0057 - val_dense_6_loss: 0.0061 - val_dense_5_mse: 0.0058 - val_dense_6_mse: 0.0062
# Epoch 57/100
# 7500/7500 [==============================] - 10s 1ms/sample - loss: 0.0132 - dense_5_loss: 0.0057 - dense_6_loss: 0.0075 - dense_5_mse: 0.0057 - dense_6_mse: 0.0075 - val_loss: 0.0117 - val_dense_5_loss: 0.0063 - val_dense_6_loss: 0.0054 - val_dense_5_mse: 0.0063 - val_dense_6_mse: 0.0054
# Epoch 58/100
# 7500/7500 [==============================] - 8s 1ms/sample - loss: 0.0132 - dense_5_loss: 0.0056 - dense_6_loss: 0.0075 - dense_5_mse: 0.0056 - dense_6_mse: 0.0075 - val_loss: 0.0101 - val_dense_5_loss: 0.0052 - val_dense_6_loss: 0.0049 - val_dense_5_mse: 0.0052 - val_dense_6_mse: 0.0049
# Epoch 59/100
# 7500/7500 [==============================] - 10s 1ms/sample - loss: 0.0127 - dense_5_loss: 0.0054 - dense_6_loss: 0.0073 - dense_5_mse: 0.0054 - dense_6_mse: 0.0073 - val_loss: 0.0104 - val_dense_5_loss: 0.0054 - val_dense_6_loss: 0.0050 - val_dense_5_mse: 0.0054 - val_dense_6_mse: 0.0050
# Epoch 60/100
# 7500/7500 [==============================] - 9s 1ms/sample - loss: 0.0134 - dense_5_loss: 0.0058 - dense_6_loss: 0.0076 - dense_5_mse: 0.0058 - dense_6_mse: 0.0077 - val_loss: 0.0131 - val_dense_5_loss: 0.0062 - val_dense_6_loss: 0.0068 - val_dense_5_mse: 0.0062 - val_dense_6_mse: 0.0069
# Epoch 61/100
# 7500/7500 [==============================] - 9s 1ms/sample - loss: 0.0129 - dense_5_loss: 0.0055 - dense_6_loss: 0.0074 - dense_5_mse: 0.0055 - dense_6_mse: 0.0074 - val_loss: 0.0114 - val_dense_5_loss: 0.0060 - val_dense_6_loss: 0.0053 - val_dense_5_mse: 0.0060 - val_dense_6_mse: 0.0053
# Epoch 62/100
# 7500/7500 [==============================] - 10s 1ms/sample - loss: 0.0129 - dense_5_loss: 0.0055 - dense_6_loss: 0.0074 - dense_5_mse: 0.0055 - dense_6_mse: 0.0074 - val_loss: 0.0101 - val_dense_5_loss: 0.0053 - val_dense_6_loss: 0.0048 - val_dense_5_mse: 0.0053 - val_dense_6_mse: 0.0048
# Epoch 62: early stopping
# ---Training time: 565.19033885 seconds ---

# %%
# Predictions: Training
y_predtrain = model.predict([X_train])
y_predtrain_SS = np.array(y_predtrain)[0,]
y_predtrain_TTF =np.array(y_predtrain)[1,]

# Predictions: Validation
y_predval = model.predict([X_val])
y_predval_SS = np.array(y_predval)[0,]
y_predval_TTF =np.array(y_predval)[1,]

# Predictions: Testing
y_predtest = model.predict([x_test])
y_predtest_SS = np.array(y_predtest)[0,]
y_predtest_TTF =np.array(y_predtest)[1,]
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
# Inverse scaling: SS
Y_train_SS = scaler_ss.inverse_transform(Y_train_SS)
Y_val_SS = scaler_ss.inverse_transform(Y_val_SS)
y_test_SS = scaler_ss.inverse_transform(y_test_SS)
y_predtrain_SS = scaler_ss.inverse_transform(y_predtrain_SS)
y_predval_SS = scaler_ss.inverse_transform(y_predval_SS)
y_predtest_SS = scaler_ss.inverse_transform(y_predtest_SS)

# Inverse scaling: TTF
Y_train_TTF = scaler_ttf.inverse_transform(Y_train_TTF)
Y_val_TTF = scaler_ttf.inverse_transform(Y_val_TTF)
y_test_TTF = scaler_ttf.inverse_transform(y_test_TTF)
y_predtrain_TTF = scaler_ttf.inverse_transform(y_predtrain_TTF)
y_predval_TTF = scaler_ttf.inverse_transform(y_predval_TTF)
y_predtest_TTF = scaler_ttf.inverse_transform(y_predtest_TTF)

# %%
# Model Performance: Training
train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

train_r2_TTF = r2_score(Y_train_TTF, y_predtrain_TTF)
train_rmse_TTF = np.sqrt(mean_squared_error(Y_train_TTF, y_predtrain_TTF))

# Model Performance: Validation
val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

val_r2_TTF = r2_score(Y_val_TTF, y_predval_TTF)
val_rmse_TTF = np.sqrt(mean_squared_error(Y_val_TTF, y_predval_TTF))

# Model Performance: Testing
test_r2_SS = r2_score(y_test_SS, y_predtest_SS)
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))

test_r2_TTF = r2_score(y_test_TTF, y_predtest_TTF)
test_rmse_TTF = np.sqrt(mean_squared_error(y_test_TTF, y_predtest_TTF))

# %%
# Print R2 Results
print("R2 scores: Train (SS) - %0.5f, Train (TTF) - %0.5f" %(train_r2_SS, train_r2_TTF))
print("R2 scores: Val (SS) - %0.5f, Val (TTF) - %0.5f" %(val_r2_SS, val_r2_TTF))
print("R2 scores: Test (SS) - %0.5f, Test (TTF) - %0.5f" %(test_r2_SS, test_r2_TTF))
# Out:
# R2 scores: Train (SS) - 0.90958, Train (TTF) - 0.90026
# R2 scores: Val (SS) - 0.92999, Val (TTF) - 0.94490
# R2 scores: Test (SS) - 0.72712, Test (TTF) - 0.75784

# %%
# Print RMSE Results
print("RMSE: Train (SS) - %0.5f, Train (TTF) - %0.5f" %(train_rmse_SS, train_rmse_TTF))
print("RMSE: Val (SS) - %0.5f, Val (TTF) - %0.5f" %(val_rmse_SS, val_rmse_TTF))
print("RMSE: Test (SS) - %0.5f, Test (TTF) - %0.5f" %(test_rmse_SS, test_rmse_TTF))
# Out:
# RMSE: Train (SS) - 0.04077, Train (TTF) - 0.90499
# RMSE: Val (SS) - 0.04084, Val (TTF) - 0.74913
# RMSE: Test (SS) - 0.07923, Test (TTF) - 1.53162
