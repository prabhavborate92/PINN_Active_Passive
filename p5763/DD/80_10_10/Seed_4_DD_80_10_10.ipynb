# %%
# Load Libraries
import pandas as pd
import numpy as np
import os
from scipy.io import loadmat
import matplotlib.pyplot as plt
import time
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.metrics import mean_squared_error
from tensorflow.python.keras.layers import Lambda
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop, Adam
from keras.layers import Dense, LSTM, TimeDistributed, Flatten, Bidirectional, Input
from sklearn.preprocessing import MinMaxScaler
import h5py
import math
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from google.colab import files
from numpy import savetxt

# %%
# Seed
np.random.seed(20)
tf.random.set_seed(20)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Change the current working directory
os.chdir('/content/drive/My Drive/Colab Notebooks/PINN_Active_Passive_Paper/p5763')
# Print the current working directory
print("Current working directory: {0}".format(os.getcwd()))
# Out:
# Current working directory: /content/drive/My Drive/Colab Notebooks/PINN_Active_Passive_Paper/p5763

# %%
# Function: Create Data History
def create_timesteps(data, n_steps):
	x = []
	y = []
	for i in range(len(data)-1):
		end_ix = i + n_steps
		if end_ix > len(data)-1:
			break
		x1, y1 = data[i:end_ix, :-1], data[end_ix, -1]
		x.append(x1)
		y.append(y1)
	return np.array(x), np.array(y)

# %%
# Load Features
os.chdir('/content/drive/My Drive/Colab Notebooks/PINN_Active_Passive_Paper/p5763/Data')
Data1 = loadmat('p5763_Set1_Inputs.mat')
Data2 = loadmat('p5763_Set1_Outputs.mat')
Features = pd.DataFrame({'Time':Data1['Time'].ravel().round(2),'K':Data1['K'].ravel().round(2),'V':Data1['V'].ravel().round(2),'AE':Data1['AE'].ravel().round(2),
                         'Amp':Data1['Amp'].ravel().round(2)})
Output = pd.DataFrame({'Time':Data2['Time'].ravel().round(2),'SS':Data2['SS'].ravel().round(2),'ln_V_V0':Data2['ln_V_V0'].ravel().round(2),'TTF':Data2['TTF'].ravel().round(2),
                       'physics_out':Data2['physics_out'].ravel().round(2), 'SR':Data2['SR'].ravel().round(2)})
df = Features.merge(Output, on = 'Time')
df = df[['K','V','AE','Amp','SS','TTF','ln_V_V0','SR','physics_out','Time']]
df_AE = df[['AE','AE']]
df_SS = df[['K','V','AE','Amp','SS']]
df_TTF = df[['K','V','AE','Amp','TTF']]
df_SR = df[['K','V','AE','Amp','ln_V_V0']]
xdf = df[['K','V','AE','Amp']]
ydf = df[['SS','TTF','ln_V_V0']]
print("Input Data:\n", xdf)
print("Target Data:\n",ydf)
# Out:
# Input Data:
#              K      V    AE      Amp
# 0     5957.24  17.78  2.00  2090.29
# 1     5960.89  17.79  2.00  2072.79
# 2     6214.84  17.81  2.00  2078.77
# 3     4543.97  17.74  2.00  2085.99
# 4     4554.15  17.76  1.67  2066.37
# ...       ...    ...   ...      ...
# 9495  1033.99  16.82  2.00  1720.64
# 9496  1032.72  16.81  2.00  1742.58
# 9497  1032.13  16.81  1.67  1732.37
# 9498  1032.36  16.81  1.67  1693.09
# 9499  1114.37  16.83  1.50  1704.66
#
# [9500 rows x 4 columns]
# Target Data:
#          SS   TTF  ln_V_V0
# 0     6.05  0.00   -11.51
# 1     6.06  0.00   -11.51
# 2     6.06  0.00   -11.51
# 3     6.07  0.00   -11.51
# 4     6.07  0.00   -11.51
# ...    ...   ...      ...
# 9495  5.92  6.55   -11.51
# 9496  5.92  6.45   -11.51
# 9497  5.93  6.34   -11.51
# 9498  5.93  6.23   -11.51
# 9499  5.94  6.12   -11.51
#
# [9500 rows x 3 columns]

# %%
# Preprocessing (AE)
arr = df_AE.to_numpy()
n_steps = 100
xdf_AE, ydf_AE = create_timesteps(arr, n_steps)

# Preprocessing (SS)
arr = df_SS.to_numpy()
n_steps = 100
xdf, ydf_SS = create_timesteps(arr, n_steps)

# Preprocessing (TTF)
arr = df_TTF.to_numpy()
n_steps = 100
xdf, ydf_TTF = create_timesteps(arr, n_steps)

# Preprocessing (SR)
arr = df_SR.to_numpy()
n_steps = 100
xdf, ydf_SR = create_timesteps(arr, n_steps)

print('Features shape, X = ', np.shape(xdf))
print('Target shape (SS), Y = ', np.shape(ydf_SS))
print('Target shape (TTF), Y = ', np.shape(ydf_TTF))
print('Target shape (SR), Y = ', np.shape(ydf_SR))
print('Target shape (AE), Y = ', np.shape(ydf_AE))

# Reshape
in_dim = xdf.shape[1]*xdf.shape[2]
xdf = xdf.reshape((xdf.shape[0], in_dim))
print('After reshaping, X = ', np.shape(xdf))

# Reshape AE
in_dim = xdf_AE.shape[1]*xdf_AE.shape[2]
xdf_AE = xdf_AE.reshape((xdf_AE.shape[0], in_dim))
print('After reshaping, xdf_AE = ', np.shape(xdf_AE))
# Out:
# Features shape, X =  (9400, 100, 4)
# Target shape (SS), Y =  (9400,)
# Target shape (TTF), Y =  (9400,)
# Target shape (SR), Y =  (9400,)
# Target shape (AE), Y =  (9400,)
# After reshaping, X =  (9400, 400)
# After reshaping, xdf_AE =  (9400, 100)

# %%
# Split into train-val-test (SS)
x_train, x_test, y_train_SS, y_test_SS = train_test_split(xdf, ydf_SS, test_size=0.1, shuffle=False)
X_train, X_val, Y_train_SS, Y_val_SS = train_test_split(x_train, y_train_SS, test_size=0.111, shuffle=False)

# Split into train-val-test (TTF)
x_train, x_test, y_train_TTF, y_test_TTF = train_test_split(xdf, ydf_TTF, test_size=0.1, shuffle=False)
X_train, X_val, Y_train_TTF, Y_val_TTF = train_test_split(x_train, y_train_TTF, test_size=0.111, shuffle=False)

# Split into train-val-test (SR)
x_train, x_test, y_train_SR, y_test_SR = train_test_split(xdf, ydf_SR, test_size=0.1, shuffle=False)
X_train, X_val, Y_train_SR, Y_val_SR = train_test_split(x_train, y_train_SR, test_size=0.111, shuffle=False)

# Split into train-val-test (AE)
x_train, x_test, y_train_AE, y_test_AE = train_test_split(xdf, xdf_AE, test_size=0.1, shuffle=False)
X_train, X_val, Y_train_AE, Y_val_AE = train_test_split(x_train, y_train_AE, test_size=0.111, shuffle=False)

# Normalize the input
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_val = pd.DataFrame(scaler.transform(X_val))
x_test = pd.DataFrame(scaler.transform(x_test))

print("Training samples:", np.shape(X_train)[0])
print("Validation samples:", np.shape(X_val)[0])
print("Testing samples:", np.shape(x_test)[0])
# Out:
# Training samples: 7520
# Validation samples: 940
# Testing samples: 940

# %%
# Normalize the output: SS
scaler_ss = MinMaxScaler(feature_range=(0, 1))
Y_train_SS = pd.DataFrame(scaler_ss.fit_transform(Y_train_SS.reshape(-1, 1)))
Y_val_SS = pd.DataFrame(scaler_ss.transform(Y_val_SS.reshape(-1, 1)))
y_test_SS = pd.DataFrame(scaler_ss.transform(y_test_SS.reshape(-1, 1)))

# %%
# Normalize the output: TTF
scaler_ttf = MinMaxScaler(feature_range=(0, 1))
Y_train_TTF = pd.DataFrame(scaler_ttf.fit_transform(Y_train_TTF.reshape(-1, 1)))
Y_val_TTF = pd.DataFrame(scaler_ttf.transform(Y_val_TTF.reshape(-1, 1)))
y_test_TTF = pd.DataFrame(scaler_ttf.transform(y_test_TTF.reshape(-1, 1)))

# %%
# # Normalize the output: SR
scaler_sr = MinMaxScaler(feature_range=(-1, 1))
Y_train_SR = pd.DataFrame(scaler_sr.fit_transform(Y_train_SR.reshape(-1, 1)))
Y_val_SR = pd.DataFrame(scaler_sr.transform(Y_val_SR.reshape(-1, 1)))
y_test_SR = pd.DataFrame(scaler_sr.transform(y_test_SR.reshape(-1, 1)))

# %%
# Normalize the input: AE
scaler_ae = MinMaxScaler(feature_range=(0, 1))
Y_train_AE = pd.DataFrame(scaler_ae.fit_transform(Y_train_AE))
Y_val_AE = pd.DataFrame(scaler_ae.transform(Y_val_AE))
y_test_AE = pd.DataFrame(scaler_ae.transform(y_test_AE))

# %%
# Define DD Model
def MLP_Physics():

  # Define inputs
  X_train = layers.Input(shape=(400),name='X_train')
  AE =layers.Input(shape=(100),name='AE')

  # Prediction: Shear Stress + TTF
  x = layers.Dense(128,kernel_initializer = 'normal', activation="relu")(X_train)
  x = layers.Dense(64,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(32,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(16, kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(8, kernel_initializer = 'normal', activation="relu")(x)

  ss_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)
  ttf_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  # # Prediction: SR
  x = layers.Dense(128,kernel_initializer = 'normal', activation="relu")(AE)
  x = layers.Dense(64,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(32,kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(16, kernel_initializer = 'normal', activation="relu")(x)
  x = layers.Dense(8, kernel_initializer = 'normal', activation="relu")(x)
  sr_pred = layers.Dense(1,kernel_initializer = 'normal',activation="linear")(x)

  model = keras.Model(inputs=[X_train,AE],outputs=[ss_pred,ttf_pred,sr_pred])
  return model

# %%
# Model Summary
model=MLP_Physics()
model.compile(loss='mse', optimizer=tf.keras.optimizers.legacy.Adam(1e-3), metrics=['mse'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  X_train (InputLayer)        [(None, 400)]                0         []
#
#  AE (InputLayer)             [(None, 100)]                0         []
#
#  dense (Dense)               (None, 128)                  51328     ['X_train[0][0]']
#
#  dense_7 (Dense)             (None, 128)                  12928     ['AE[0][0]']
#
#  dense_1 (Dense)             (None, 64)                   8256      ['dense[0][0]']
#
#  dense_8 (Dense)             (None, 64)                   8256      ['dense_7[0][0]']
#
#  dense_2 (Dense)             (None, 32)                   2080      ['dense_1[0][0]']
#
#  dense_9 (Dense)             (None, 32)                   2080      ['dense_8[0][0]']
#
#  dense_3 (Dense)             (None, 16)                   528       ['dense_2[0][0]']
#
#  dense_10 (Dense)            (None, 16)                   528       ['dense_9[0][0]']
#
#  dense_4 (Dense)             (None, 8)                    136       ['dense_3[0][0]']
#
#  dense_11 (Dense)            (None, 8)                    136       ['dense_10[0][0]']
#
#  dense_5 (Dense)             (None, 1)                    9         ['dense_4[0][0]']
#
#  dense_6 (Dense)             (None, 1)                    9         ['dense_4[0][0]']
#
#  dense_12 (Dense)            (None, 1)                    9         ['dense_11[0][0]']
#
# ==================================================================================================
# Total params: 86283 (337.04 KB)
# Trainable params: 86283 (337.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Train The Model
start_time = time.time()
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20,verbose=1, mode='auto')
callbacks_list = [earlystop]
history = model.fit([X_train,Y_train_AE],[Y_train_SS,Y_train_TTF,Y_train_SR], epochs=100, batch_size=32,callbacks=callbacks_list,
                     validation_data=([X_val,Y_val_AE],[Y_val_SS,Y_val_TTF,Y_val_SR]), verbose=1)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
end_time = time.time()
print("---Training time: %0.8f seconds ---" % (end_time - start_time))
# Out:
# Train on 7520 samples, validate on 940 samples
# Epoch 1/100
# 7520/7520 [==============================] - 2s 332us/sample - loss: 0.4221 - dense_5_loss: 0.0896 - dense_6_loss: 0.1037 - dense_12_loss: 0.2289 - dense_5_mse: 0.0896 - dense_6_mse: 0.1037 - dense_12_mse: 0.2289 - val_loss: 0.2186 - val_dense_5_loss: 0.0444 - val_dense_6_loss: 0.1309 - val_dense_12_loss: 0.0402 - val_dense_5_mse: 0.0449 - val_dense_6_mse: 0.1327 - val_dense_12_mse: 0.0410
# Epoch 2/100
#   32/7520 [..............................] - ETA: 1s - loss: 0.2482 - dense_5_loss: 0.0383 - dense_6_loss: 0.1039 - dense_12_loss: 0.1060 - dense_5_mse: 0.0383 - dense_6_mse: 0.1039 - dense_12_mse: 0.1060
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 7520/7520 [==============================] - 1s 103us/sample - loss: 0.1583 - dense_5_loss: 0.0279 - dense_6_loss: 0.0932 - dense_12_loss: 0.0373 - dense_5_mse: 0.0279 - dense_6_mse: 0.0932 - dense_12_mse: 0.0373 - val_loss: 0.2066 - val_dense_5_loss: 0.0266 - val_dense_6_loss: 0.1428 - val_dense_12_loss: 0.0361 - val_dense_5_mse: 0.0268 - val_dense_6_mse: 0.1432 - val_dense_12_mse: 0.0366
# Epoch 3/100
# 7520/7520 [==============================] - 1s 103us/sample - loss: 0.1378 - dense_5_loss: 0.0129 - dense_6_loss: 0.0934 - dense_12_loss: 0.0315 - dense_5_mse: 0.0129 - dense_6_mse: 0.0934 - dense_12_mse: 0.0315 - val_loss: 0.1651 - val_dense_5_loss: 0.0111 - val_dense_6_loss: 0.1242 - val_dense_12_loss: 0.0296 - val_dense_5_mse: 0.0108 - val_dense_6_mse: 0.1245 - val_dense_12_mse: 0.0298
# Epoch 4/100
# 7520/7520 [==============================] - 1s 99us/sample - loss: 0.0589 - dense_5_loss: 0.0062 - dense_6_loss: 0.0250 - dense_12_loss: 0.0277 - dense_5_mse: 0.0062 - dense_6_mse: 0.0250 - dense_12_mse: 0.0277 - val_loss: 0.0519 - val_dense_5_loss: 0.0110 - val_dense_6_loss: 0.0157 - val_dense_12_loss: 0.0298 - val_dense_5_mse: 0.0104 - val_dense_6_mse: 0.0148 - val_dense_12_mse: 0.0266
# Epoch 5/100
# 7520/7520 [==============================] - 1s 103us/sample - loss: 0.0365 - dense_5_loss: 0.0045 - dense_6_loss: 0.0076 - dense_12_loss: 0.0244 - dense_5_mse: 0.0045 - dense_6_mse: 0.0076 - dense_12_mse: 0.0244 - val_loss: 0.0434 - val_dense_5_loss: 0.0101 - val_dense_6_loss: 0.0103 - val_dense_12_loss: 0.0225 - val_dense_5_mse: 0.0102 - val_dense_6_mse: 0.0103 - val_dense_12_mse: 0.0229
# Epoch 6/100
# 7520/7520 [==============================] - 1s 97us/sample - loss: 0.0318 - dense_5_loss: 0.0040 - dense_6_loss: 0.0067 - dense_12_loss: 0.0211 - dense_5_mse: 0.0040 - dense_6_mse: 0.0067 - dense_12_mse: 0.0211 - val_loss: 0.0451 - val_dense_5_loss: 0.0108 - val_dense_6_loss: 0.0110 - val_dense_12_loss: 0.0264 - val_dense_5_mse: 0.0102 - val_dense_6_mse: 0.0101 - val_dense_12_mse: 0.0248
# Epoch 7/100
# 7520/7520 [==============================] - 1s 106us/sample - loss: 0.0301 - dense_5_loss: 0.0038 - dense_6_loss: 0.0064 - dense_12_loss: 0.0199 - dense_5_mse: 0.0038 - dense_6_mse: 0.0064 - dense_12_mse: 0.0199 - val_loss: 0.0377 - val_dense_5_loss: 0.0091 - val_dense_6_loss: 0.0115 - val_dense_12_loss: 0.0169 - val_dense_5_mse: 0.0089 - val_dense_6_mse: 0.0115 - val_dense_12_mse: 0.0172
# Epoch 8/100
# 7520/7520 [==============================] - 1s 100us/sample - loss: 0.0271 - dense_5_loss: 0.0037 - dense_6_loss: 0.0062 - dense_12_loss: 0.0171 - dense_5_mse: 0.0037 - dense_6_mse: 0.0062 - dense_12_mse: 0.0171 - val_loss: 0.0270 - val_dense_5_loss: 0.0086 - val_dense_6_loss: 0.0103 - val_dense_12_loss: 0.0080 - val_dense_5_mse: 0.0086 - val_dense_6_mse: 0.0104 - val_dense_12_mse: 0.0081
# Epoch 9/100
# 7520/7520 [==============================] - 1s 100us/sample - loss: 0.0234 - dense_5_loss: 0.0034 - dense_6_loss: 0.0058 - dense_12_loss: 0.0142 - dense_5_mse: 0.0034 - dense_6_mse: 0.0058 - dense_12_mse: 0.0142 - val_loss: 0.0279 - val_dense_5_loss: 0.0121 - val_dense_6_loss: 0.0084 - val_dense_12_loss: 0.0072 - val_dense_5_mse: 0.0121 - val_dense_6_mse: 0.0085 - val_dense_12_mse: 0.0073
# Epoch 10/100
# 7520/7520 [==============================] - 1s 140us/sample - loss: 0.0187 - dense_5_loss: 0.0033 - dense_6_loss: 0.0057 - dense_12_loss: 0.0097 - dense_5_mse: 0.0033 - dense_6_mse: 0.0057 - dense_12_mse: 0.0097 - val_loss: 0.0249 - val_dense_5_loss: 0.0096 - val_dense_6_loss: 0.0093 - val_dense_12_loss: 0.0059 - val_dense_5_mse: 0.0097 - val_dense_6_mse: 0.0093 - val_dense_12_mse: 0.0059
# Epoch 11/100
# 7520/7520 [==============================] - 1s 177us/sample - loss: 0.0175 - dense_5_loss: 0.0032 - dense_6_loss: 0.0054 - dense_12_loss: 0.0089 - dense_5_mse: 0.0032 - dense_6_mse: 0.0054 - dense_12_mse: 0.0089 - val_loss: 0.0258 - val_dense_5_loss: 0.0104 - val_dense_6_loss: 0.0093 - val_dense_12_loss: 0.0060 - val_dense_5_mse: 0.0104 - val_dense_6_mse: 0.0093 - val_dense_12_mse: 0.0061
# Epoch 12/100
# 7520/7520 [==============================] - 2s 201us/sample - loss: 0.0160 - dense_5_loss: 0.0030 - dense_6_loss: 0.0053 - dense_12_loss: 0.0077 - dense_5_mse: 0.0030 - dense_6_mse: 0.0053 - dense_12_mse: 0.0077 - val_loss: 0.0274 - val_dense_5_loss: 0.0125 - val_dense_6_loss: 0.0081 - val_dense_12_loss: 0.0065 - val_dense_5_mse: 0.0126 - val_dense_6_mse: 0.0082 - val_dense_12_mse: 0.0066
# Epoch 13/100
# 7520/7520 [==============================] - 2s 208us/sample - loss: 0.0166 - dense_5_loss: 0.0029 - dense_6_loss: 0.0052 - dense_12_loss: 0.0084 - dense_5_mse: 0.0029 - dense_6_mse: 0.0052 - dense_12_mse: 0.0084 - val_loss: 0.0245 - val_dense_5_loss: 0.0135 - val_dense_6_loss: 0.0078 - val_dense_12_loss: 0.0028 - val_dense_5_mse: 0.0137 - val_dense_6_mse: 0.0079 - val_dense_12_mse: 0.0028
# Epoch 14/100
# 7520/7520 [==============================] - 1s 147us/sample - loss: 0.0150 - dense_5_loss: 0.0031 - dense_6_loss: 0.0050 - dense_12_loss: 0.0069 - dense_5_mse: 0.0031 - dense_6_mse: 0.0050 - dense_12_mse: 0.0069 - val_loss: 0.0279 - val_dense_5_loss: 0.0142 - val_dense_6_loss: 0.0091 - val_dense_12_loss: 0.0047 - val_dense_5_mse: 0.0141 - val_dense_6_mse: 0.0090 - val_dense_12_mse: 0.0048
# Epoch 15/100
# 7520/7520 [==============================] - 1s 107us/sample - loss: 0.0153 - dense_5_loss: 0.0029 - dense_6_loss: 0.0050 - dense_12_loss: 0.0074 - dense_5_mse: 0.0029 - dense_6_mse: 0.0050 - dense_12_mse: 0.0074 - val_loss: 0.0307 - val_dense_5_loss: 0.0142 - val_dense_6_loss: 0.0068 - val_dense_12_loss: 0.0094 - val_dense_5_mse: 0.0142 - val_dense_6_mse: 0.0069 - val_dense_12_mse: 0.0095
# Epoch 16/100
# 7520/7520 [==============================] - 1s 101us/sample - loss: 0.0138 - dense_5_loss: 0.0027 - dense_6_loss: 0.0048 - dense_12_loss: 0.0063 - dense_5_mse: 0.0027 - dense_6_mse: 0.0048 - dense_12_mse: 0.0063 - val_loss: 0.0183 - val_dense_5_loss: 0.0072 - val_dense_6_loss: 0.0075 - val_dense_12_loss: 0.0041 - val_dense_5_mse: 0.0070 - val_dense_6_mse: 0.0071 - val_dense_12_mse: 0.0042
# Epoch 17/100
# 7520/7520 [==============================] - 1s 99us/sample - loss: 0.0137 - dense_5_loss: 0.0027 - dense_6_loss: 0.0046 - dense_12_loss: 0.0064 - dense_5_mse: 0.0027 - dense_6_mse: 0.0046 - dense_12_mse: 0.0064 - val_loss: 0.0251 - val_dense_5_loss: 0.0129 - val_dense_6_loss: 0.0079 - val_dense_12_loss: 0.0039 - val_dense_5_mse: 0.0131 - val_dense_6_mse: 0.0080 - val_dense_12_mse: 0.0040
# Epoch 18/100
# 7520/7520 [==============================] - 1s 101us/sample - loss: 0.0129 - dense_5_loss: 0.0026 - dense_6_loss: 0.0045 - dense_12_loss: 0.0058 - dense_5_mse: 0.0026 - dense_6_mse: 0.0045 - dense_12_mse: 0.0058 - val_loss: 0.0238 - val_dense_5_loss: 0.0094 - val_dense_6_loss: 0.0087 - val_dense_12_loss: 0.0075 - val_dense_5_mse: 0.0086 - val_dense_6_mse: 0.0075 - val_dense_12_mse: 0.0076
# Epoch 19/100
# 7520/7520 [==============================] - 1s 102us/sample - loss: 0.0127 - dense_5_loss: 0.0026 - dense_6_loss: 0.0044 - dense_12_loss: 0.0057 - dense_5_mse: 0.0026 - dense_6_mse: 0.0044 - dense_12_mse: 0.0057 - val_loss: 0.0220 - val_dense_5_loss: 0.0068 - val_dense_6_loss: 0.0072 - val_dense_12_loss: 0.0077 - val_dense_5_mse: 0.0068 - val_dense_6_mse: 0.0073 - val_dense_12_mse: 0.0078
# Epoch 20/100
# 7520/7520 [==============================] - 1s 98us/sample - loss: 0.0128 - dense_5_loss: 0.0025 - dense_6_loss: 0.0044 - dense_12_loss: 0.0058 - dense_5_mse: 0.0025 - dense_6_mse: 0.0044 - dense_12_mse: 0.0058 - val_loss: 0.0259 - val_dense_5_loss: 0.0070 - val_dense_6_loss: 0.0065 - val_dense_12_loss: 0.0120 - val_dense_5_mse: 0.0071 - val_dense_6_mse: 0.0066 - val_dense_12_mse: 0.0122
# Epoch 21/100
# 7520/7520 [==============================] - 1s 106us/sample - loss: 0.0126 - dense_5_loss: 0.0025 - dense_6_loss: 0.0045 - dense_12_loss: 0.0056 - dense_5_mse: 0.0025 - dense_6_mse: 0.0045 - dense_12_mse: 0.0056 - val_loss: 0.0335 - val_dense_5_loss: 0.0085 - val_dense_6_loss: 0.0080 - val_dense_12_loss: 0.0164 - val_dense_5_mse: 0.0086 - val_dense_6_mse: 0.0081 - val_dense_12_mse: 0.0168
# Epoch 22/100
# 7520/7520 [==============================] - 1s 105us/sample - loss: 0.0120 - dense_5_loss: 0.0024 - dense_6_loss: 0.0043 - dense_12_loss: 0.0053 - dense_5_mse: 0.0024 - dense_6_mse: 0.0043 - dense_12_mse: 0.0053 - val_loss: 0.0285 - val_dense_5_loss: 0.0083 - val_dense_6_loss: 0.0067 - val_dense_12_loss: 0.0132 - val_dense_5_mse: 0.0083 - val_dense_6_mse: 0.0068 - val_dense_12_mse: 0.0135
# Epoch 23/100
# 7520/7520 [==============================] - 1s 101us/sample - loss: 0.0118 - dense_5_loss: 0.0023 - dense_6_loss: 0.0040 - dense_12_loss: 0.0055 - dense_5_mse: 0.0023 - dense_6_mse: 0.0040 - dense_12_mse: 0.0055 - val_loss: 0.0237 - val_dense_5_loss: 0.0115 - val_dense_6_loss: 0.0056 - val_dense_12_loss: 0.0064 - val_dense_5_mse: 0.0114 - val_dense_6_mse: 0.0057 - val_dense_12_mse: 0.0066
# Epoch 24/100
# 7520/7520 [==============================] - 1s 104us/sample - loss: 0.0110 - dense_5_loss: 0.0023 - dense_6_loss: 0.0042 - dense_12_loss: 0.0045 - dense_5_mse: 0.0023 - dense_6_mse: 0.0042 - dense_12_mse: 0.0045 - val_loss: 0.0213 - val_dense_5_loss: 0.0082 - val_dense_6_loss: 0.0070 - val_dense_12_loss: 0.0058 - val_dense_5_mse: 0.0083 - val_dense_6_mse: 0.0071 - val_dense_12_mse: 0.0059
# Epoch 25/100
# 7520/7520 [==============================] - 1s 98us/sample - loss: 0.0110 - dense_5_loss: 0.0023 - dense_6_loss: 0.0041 - dense_12_loss: 0.0046 - dense_5_mse: 0.0023 - dense_6_mse: 0.0041 - dense_12_mse: 0.0046 - val_loss: 0.0195 - val_dense_5_loss: 0.0062 - val_dense_6_loss: 0.0064 - val_dense_12_loss: 0.0067 - val_dense_5_mse: 0.0062 - val_dense_6_mse: 0.0065 - val_dense_12_mse: 0.0068
# Epoch 26/100
# 7520/7520 [==============================] - 1s 102us/sample - loss: 0.0122 - dense_5_loss: 0.0024 - dense_6_loss: 0.0041 - dense_12_loss: 0.0056 - dense_5_mse: 0.0024 - dense_6_mse: 0.0041 - dense_12_mse: 0.0056 - val_loss: 0.0182 - val_dense_5_loss: 0.0064 - val_dense_6_loss: 0.0055 - val_dense_12_loss: 0.0061 - val_dense_5_mse: 0.0065 - val_dense_6_mse: 0.0055 - val_dense_12_mse: 0.0062
# Epoch 27/100
# 7520/7520 [==============================] - 1s 150us/sample - loss: 0.0119 - dense_5_loss: 0.0024 - dense_6_loss: 0.0040 - dense_12_loss: 0.0055 - dense_5_mse: 0.0024 - dense_6_mse: 0.0040 - dense_12_mse: 0.0055 - val_loss: 0.0192 - val_dense_5_loss: 0.0076 - val_dense_6_loss: 0.0050 - val_dense_12_loss: 0.0062 - val_dense_5_mse: 0.0077 - val_dense_6_mse: 0.0051 - val_dense_12_mse: 0.0064
# Epoch 28/100
# 7520/7520 [==============================] - 1s 184us/sample - loss: 0.0111 - dense_5_loss: 0.0021 - dense_6_loss: 0.0038 - dense_12_loss: 0.0051 - dense_5_mse: 0.0021 - dense_6_mse: 0.0038 - dense_12_mse: 0.0051 - val_loss: 0.0215 - val_dense_5_loss: 0.0077 - val_dense_6_loss: 0.0052 - val_dense_12_loss: 0.0082 - val_dense_5_mse: 0.0078 - val_dense_6_mse: 0.0052 - val_dense_12_mse: 0.0084
# Epoch 29/100
# 7520/7520 [==============================] - 1s 178us/sample - loss: 0.0112 - dense_5_loss: 0.0022 - dense_6_loss: 0.0038 - dense_12_loss: 0.0053 - dense_5_mse: 0.0022 - dense_6_mse: 0.0038 - dense_12_mse: 0.0053 - val_loss: 0.0236 - val_dense_5_loss: 0.0077 - val_dense_6_loss: 0.0075 - val_dense_12_loss: 0.0081 - val_dense_5_mse: 0.0078 - val_dense_6_mse: 0.0076 - val_dense_12_mse: 0.0082
# Epoch 30/100
# 7520/7520 [==============================] - 1s 176us/sample - loss: 0.0116 - dense_5_loss: 0.0022 - dense_6_loss: 0.0040 - dense_12_loss: 0.0054 - dense_5_mse: 0.0022 - dense_6_mse: 0.0040 - dense_12_mse: 0.0054 - val_loss: 0.0200 - val_dense_5_loss: 0.0076 - val_dense_6_loss: 0.0051 - val_dense_12_loss: 0.0070 - val_dense_5_mse: 0.0077 - val_dense_6_mse: 0.0052 - val_dense_12_mse: 0.0071
# Epoch 31/100
# 7520/7520 [==============================] - 1s 91us/sample - loss: 0.0121 - dense_5_loss: 0.0021 - dense_6_loss: 0.0038 - dense_12_loss: 0.0061 - dense_5_mse: 0.0021 - dense_6_mse: 0.0038 - dense_12_mse: 0.0061 - val_loss: 0.0207 - val_dense_5_loss: 0.0073 - val_dense_6_loss: 0.0063 - val_dense_12_loss: 0.0069 - val_dense_5_mse: 0.0073 - val_dense_6_mse: 0.0064 - val_dense_12_mse: 0.0071
# Epoch 32/100
# 7520/7520 [==============================] - 1s 94us/sample - loss: 0.0117 - dense_5_loss: 0.0022 - dense_6_loss: 0.0039 - dense_12_loss: 0.0056 - dense_5_mse: 0.0022 - dense_6_mse: 0.0039 - dense_12_mse: 0.0056 - val_loss: 0.0257 - val_dense_5_loss: 0.0090 - val_dense_6_loss: 0.0068 - val_dense_12_loss: 0.0110 - val_dense_5_mse: 0.0084 - val_dense_6_mse: 0.0061 - val_dense_12_mse: 0.0112
# Epoch 33/100
# 7520/7520 [==============================] - 1s 97us/sample - loss: 0.0103 - dense_5_loss: 0.0022 - dense_6_loss: 0.0037 - dense_12_loss: 0.0045 - dense_5_mse: 0.0022 - dense_6_mse: 0.0037 - dense_12_mse: 0.0045 - val_loss: 0.0101 - val_dense_5_loss: 0.0045 - val_dense_6_loss: 0.0050 - val_dense_12_loss: 5.1638e-04 - val_dense_5_mse: 0.0045 - val_dense_6_mse: 0.0050 - val_dense_12_mse: 5.2347e-04
# Epoch 34/100
# 7520/7520 [==============================] - 1s 102us/sample - loss: 0.0098 - dense_5_loss: 0.0021 - dense_6_loss: 0.0037 - dense_12_loss: 0.0040 - dense_5_mse: 0.0021 - dense_6_mse: 0.0037 - dense_12_mse: 0.0040 - val_loss: 0.0198 - val_dense_5_loss: 0.0063 - val_dense_6_loss: 0.0069 - val_dense_12_loss: 0.0066 - val_dense_5_mse: 0.0063 - val_dense_6_mse: 0.0067 - val_dense_12_mse: 0.0068
# Epoch 35/100
# 7520/7520 [==============================] - 1s 97us/sample - loss: 0.0101 - dense_5_loss: 0.0022 - dense_6_loss: 0.0037 - dense_12_loss: 0.0042 - dense_5_mse: 0.0022 - dense_6_mse: 0.0037 - dense_12_mse: 0.0042 - val_loss: 0.0205 - val_dense_5_loss: 0.0060 - val_dense_6_loss: 0.0072 - val_dense_12_loss: 0.0069 - val_dense_5_mse: 0.0061 - val_dense_6_mse: 0.0074 - val_dense_12_mse: 0.0070
# Epoch 36/100
# 7520/7520 [==============================] - 1s 104us/sample - loss: 0.0103 - dense_5_loss: 0.0020 - dense_6_loss: 0.0037 - dense_12_loss: 0.0046 - dense_5_mse: 0.0020 - dense_6_mse: 0.0037 - dense_12_mse: 0.0046 - val_loss: 0.0227 - val_dense_5_loss: 0.0057 - val_dense_6_loss: 0.0045 - val_dense_12_loss: 0.0124 - val_dense_5_mse: 0.0056 - val_dense_6_mse: 0.0045 - val_dense_12_mse: 0.0126
# Epoch 37/100
# 7520/7520 [==============================] - 1s 104us/sample - loss: 0.0112 - dense_5_loss: 0.0020 - dense_6_loss: 0.0036 - dense_12_loss: 0.0055 - dense_5_mse: 0.0020 - dense_6_mse: 0.0036 - dense_12_mse: 0.0055 - val_loss: 0.0190 - val_dense_5_loss: 0.0049 - val_dense_6_loss: 0.0046 - val_dense_12_loss: 0.0091 - val_dense_5_mse: 0.0050 - val_dense_6_mse: 0.0047 - val_dense_12_mse: 0.0093
# Epoch 38/100
# 7520/7520 [==============================] - 1s 98us/sample - loss: 0.0106 - dense_5_loss: 0.0019 - dense_6_loss: 0.0035 - dense_12_loss: 0.0053 - dense_5_mse: 0.0019 - dense_6_mse: 0.0035 - dense_12_mse: 0.0053 - val_loss: 0.0111 - val_dense_5_loss: 0.0068 - val_dense_6_loss: 0.0039 - val_dense_12_loss: 3.8183e-04 - val_dense_5_mse: 0.0068 - val_dense_6_mse: 0.0040 - val_dense_12_mse: 3.8874e-04
# Epoch 39/100
# 7520/7520 [==============================] - 1s 102us/sample - loss: 0.0111 - dense_5_loss: 0.0019 - dense_6_loss: 0.0035 - dense_12_loss: 0.0056 - dense_5_mse: 0.0019 - dense_6_mse: 0.0035 - dense_12_mse: 0.0056 - val_loss: 0.0235 - val_dense_5_loss: 0.0092 - val_dense_6_loss: 0.0062 - val_dense_12_loss: 0.0076 - val_dense_5_mse: 0.0094 - val_dense_6_mse: 0.0064 - val_dense_12_mse: 0.0078
# Epoch 40/100
# 7520/7520 [==============================] - 1s 103us/sample - loss: 0.0111 - dense_5_loss: 0.0019 - dense_6_loss: 0.0036 - dense_12_loss: 0.0056 - dense_5_mse: 0.0019 - dense_6_mse: 0.0036 - dense_12_mse: 0.0056 - val_loss: 0.0180 - val_dense_5_loss: 0.0059 - val_dense_6_loss: 0.0041 - val_dense_12_loss: 0.0077 - val_dense_5_mse: 0.0059 - val_dense_6_mse: 0.0042 - val_dense_12_mse: 0.0079
# Epoch 41/100
# 7520/7520 [==============================] - 1s 107us/sample - loss: 0.0117 - dense_5_loss: 0.0019 - dense_6_loss: 0.0035 - dense_12_loss: 0.0063 - dense_5_mse: 0.0019 - dense_6_mse: 0.0035 - dense_12_mse: 0.0063 - val_loss: 0.0211 - val_dense_5_loss: 0.0069 - val_dense_6_loss: 0.0056 - val_dense_12_loss: 0.0083 - val_dense_5_mse: 0.0069 - val_dense_6_mse: 0.0057 - val_dense_12_mse: 0.0084
# Epoch 42/100
# 7520/7520 [==============================] - 1s 101us/sample - loss: 0.0097 - dense_5_loss: 0.0020 - dense_6_loss: 0.0035 - dense_12_loss: 0.0042 - dense_5_mse: 0.0020 - dense_6_mse: 0.0035 - dense_12_mse: 0.0042 - val_loss: 0.0137 - val_dense_5_loss: 0.0055 - val_dense_6_loss: 0.0053 - val_dense_12_loss: 0.0027 - val_dense_5_mse: 0.0056 - val_dense_6_mse: 0.0054 - val_dense_12_mse: 0.0027
# Epoch 43/100
# 7520/7520 [==============================] - 1s 98us/sample - loss: 0.0111 - dense_5_loss: 0.0019 - dense_6_loss: 0.0034 - dense_12_loss: 0.0058 - dense_5_mse: 0.0019 - dense_6_mse: 0.0034 - dense_12_mse: 0.0058 - val_loss: 0.0223 - val_dense_5_loss: 0.0092 - val_dense_6_loss: 0.0050 - val_dense_12_loss: 0.0081 - val_dense_5_mse: 0.0092 - val_dense_6_mse: 0.0049 - val_dense_12_mse: 0.0082
# Epoch 44/100
# 7520/7520 [==============================] - 1s 179us/sample - loss: 0.0109 - dense_5_loss: 0.0019 - dense_6_loss: 0.0035 - dense_12_loss: 0.0054 - dense_5_mse: 0.0019 - dense_6_mse: 0.0035 - dense_12_mse: 0.0054 - val_loss: 0.0137 - val_dense_5_loss: 0.0091 - val_dense_6_loss: 0.0036 - val_dense_12_loss: 7.9553e-04 - val_dense_5_mse: 0.0092 - val_dense_6_mse: 0.0037 - val_dense_12_mse: 8.0625e-04
# Epoch 45/100
# 7520/7520 [==============================] - 1s 182us/sample - loss: 0.0098 - dense_5_loss: 0.0019 - dense_6_loss: 0.0036 - dense_12_loss: 0.0042 - dense_5_mse: 0.0019 - dense_6_mse: 0.0036 - dense_12_mse: 0.0042 - val_loss: 0.0142 - val_dense_5_loss: 0.0042 - val_dense_6_loss: 0.0033 - val_dense_12_loss: 0.0063 - val_dense_5_mse: 0.0043 - val_dense_6_mse: 0.0034 - val_dense_12_mse: 0.0065
# Epoch 46/100
# 7520/7520 [==============================] - 1s 193us/sample - loss: 0.0091 - dense_5_loss: 0.0018 - dense_6_loss: 0.0034 - dense_12_loss: 0.0039 - dense_5_mse: 0.0018 - dense_6_mse: 0.0034 - dense_12_mse: 0.0039 - val_loss: 0.0140 - val_dense_5_loss: 0.0080 - val_dense_6_loss: 0.0048 - val_dense_12_loss: 0.0019 - val_dense_5_mse: 0.0078 - val_dense_6_mse: 0.0042 - val_dense_12_mse: 0.0020
# Epoch 47/100
# 7520/7520 [==============================] - 1s 155us/sample - loss: 0.0100 - dense_5_loss: 0.0018 - dense_6_loss: 0.0036 - dense_12_loss: 0.0046 - dense_5_mse: 0.0018 - dense_6_mse: 0.0036 - dense_12_mse: 0.0046 - val_loss: 0.0200 - val_dense_5_loss: 0.0063 - val_dense_6_loss: 0.0065 - val_dense_12_loss: 0.0069 - val_dense_5_mse: 0.0063 - val_dense_6_mse: 0.0066 - val_dense_12_mse: 0.0071
# Epoch 48/100
# 7520/7520 [==============================] - 1s 105us/sample - loss: 0.0090 - dense_5_loss: 0.0019 - dense_6_loss: 0.0034 - dense_12_loss: 0.0038 - dense_5_mse: 0.0019 - dense_6_mse: 0.0034 - dense_12_mse: 0.0038 - val_loss: 0.0186 - val_dense_5_loss: 0.0066 - val_dense_6_loss: 0.0043 - val_dense_12_loss: 0.0078 - val_dense_5_mse: 0.0064 - val_dense_6_mse: 0.0042 - val_dense_12_mse: 0.0080
# Epoch 49/100
# 7520/7520 [==============================] - 1s 108us/sample - loss: 0.0106 - dense_5_loss: 0.0016 - dense_6_loss: 0.0033 - dense_12_loss: 0.0056 - dense_5_mse: 0.0016 - dense_6_mse: 0.0033 - dense_12_mse: 0.0056 - val_loss: 0.0216 - val_dense_5_loss: 0.0082 - val_dense_6_loss: 0.0056 - val_dense_12_loss: 0.0074 - val_dense_5_mse: 0.0083 - val_dense_6_mse: 0.0057 - val_dense_12_mse: 0.0075
# Epoch 50/100
# 7520/7520 [==============================] - 1s 101us/sample - loss: 0.0097 - dense_5_loss: 0.0019 - dense_6_loss: 0.0033 - dense_12_loss: 0.0045 - dense_5_mse: 0.0019 - dense_6_mse: 0.0033 - dense_12_mse: 0.0045 - val_loss: 0.0185 - val_dense_5_loss: 0.0051 - val_dense_6_loss: 0.0063 - val_dense_12_loss: 0.0068 - val_dense_5_mse: 0.0052 - val_dense_6_mse: 0.0064 - val_dense_12_mse: 0.0069
# Epoch 51/100
# 7520/7520 [==============================] - 1s 104us/sample - loss: 0.0091 - dense_5_loss: 0.0018 - dense_6_loss: 0.0037 - dense_12_loss: 0.0036 - dense_5_mse: 0.0018 - dense_6_mse: 0.0037 - dense_12_mse: 0.0036 - val_loss: 0.0204 - val_dense_5_loss: 0.0057 - val_dense_6_loss: 0.0046 - val_dense_12_loss: 0.0099 - val_dense_5_mse: 0.0057 - val_dense_6_mse: 0.0046 - val_dense_12_mse: 0.0101
# Epoch 52/100
# 7520/7520 [==============================] - 1s 106us/sample - loss: 0.0085 - dense_5_loss: 0.0017 - dense_6_loss: 0.0032 - dense_12_loss: 0.0036 - dense_5_mse: 0.0017 - dense_6_mse: 0.0032 - dense_12_mse: 0.0036 - val_loss: 0.0182 - val_dense_5_loss: 0.0057 - val_dense_6_loss: 0.0048 - val_dense_12_loss: 0.0073 - val_dense_5_mse: 0.0058 - val_dense_6_mse: 0.0049 - val_dense_12_mse: 0.0075
# Epoch 53/100
# 7520/7520 [==============================] - 1s 111us/sample - loss: 0.0098 - dense_5_loss: 0.0018 - dense_6_loss: 0.0033 - dense_12_loss: 0.0047 - dense_5_mse: 0.0018 - dense_6_mse: 0.0033 - dense_12_mse: 0.0047 - val_loss: 0.0164 - val_dense_5_loss: 0.0054 - val_dense_6_loss: 0.0030 - val_dense_12_loss: 0.0078 - val_dense_5_mse: 0.0055 - val_dense_6_mse: 0.0030 - val_dense_12_mse: 0.0079
# Epoch 53: early stopping
# ---Training time: 53.88371181 seconds ---

# %%
# # # Save the model
# print(model.summary())
# # plot_model(model, show_shapes=True)
# model.save('/content/drive/My Drive/Colab Notebooks/PINN_Active_Passive_Paper/p5763/Standalone_Model/MLP_Data_Driven/70_10_20/DD_Transfer_model_70_10_20.h5')

# %%
# Predictions: Training
y_predtrain = model.predict([X_train,Y_train_AE])
y_predtrain_SS = np.array(y_predtrain)[0,]
y_predtrain_TTF =np.array(y_predtrain)[1,]
y_predtrain_SR =np.array(y_predtrain)[2,]

# Predictions: Validation
y_predval = model.predict([X_val,Y_val_AE])
y_predval_SS = np.array(y_predval)[0,]
y_predval_TTF =np.array(y_predval)[1,]
y_predval_SR =np.array(y_predval)[2,]

# Predictions: Testing
y_predtest = model.predict([x_test,y_test_AE])
y_predtest_SS = np.array(y_predtest)[0,]
y_predtest_TTF =np.array(y_predtest)[1,]
y_predtest_SR =np.array(y_predtest)[2,]
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
# Inverse scaling: SS
Y_train_SS = scaler_ss.inverse_transform(Y_train_SS)
Y_val_SS = scaler_ss.inverse_transform(Y_val_SS)
y_test_SS = scaler_ss.inverse_transform(y_test_SS)
y_predtrain_SS = scaler_ss.inverse_transform(y_predtrain_SS)
y_predval_SS = scaler_ss.inverse_transform(y_predval_SS)
y_predtest_SS = scaler_ss.inverse_transform(y_predtest_SS)

# Inverse scaling: TTF
Y_train_TTF = scaler_ttf.inverse_transform(Y_train_TTF)
Y_val_TTF = scaler_ttf.inverse_transform(Y_val_TTF)
y_test_TTF = scaler_ttf.inverse_transform(y_test_TTF)
y_predtrain_TTF = scaler_ttf.inverse_transform(y_predtrain_TTF)
y_predval_TTF = scaler_ttf.inverse_transform(y_predval_TTF)
y_predtest_TTF = scaler_ttf.inverse_transform(y_predtest_TTF)

# Inverse scaling: SR
Y_train_SR = scaler_sr.inverse_transform(Y_train_SR)
Y_val_SR = scaler_sr.inverse_transform(Y_val_SR)
y_test_SR = scaler_sr.inverse_transform(y_test_SR)
y_predtrain_SR = scaler_sr.inverse_transform(y_predtrain_SR)
y_predval_SR = scaler_sr.inverse_transform(y_predval_SR)
y_predtest_SR = scaler_sr.inverse_transform(y_predtest_SR)

# %%
# Model Performance: Training
train_r2_SS = r2_score(Y_train_SS, y_predtrain_SS)
train_rmse_SS = np.sqrt(mean_squared_error(Y_train_SS, y_predtrain_SS))

train_r2_TTF = r2_score(Y_train_TTF, y_predtrain_TTF)
train_rmse_TTF = np.sqrt(mean_squared_error(Y_train_TTF, y_predtrain_TTF))

train_r2_SR = r2_score(Y_train_SR, y_predtrain_SR)
train_rmse_SR = np.sqrt(mean_squared_error(Y_train_SR, y_predtrain_SR))

# Model Performance: Validation
val_r2_SS = r2_score(Y_val_SS, y_predval_SS)
val_rmse_SS = np.sqrt(mean_squared_error(Y_val_SS, y_predval_SS))

val_r2_TTF = r2_score(Y_val_TTF, y_predval_TTF)
val_rmse_TTF = np.sqrt(mean_squared_error(Y_val_TTF, y_predval_TTF))

val_r2_SR = r2_score(Y_val_SR, y_predval_SR)
val_rmse_SR = np.sqrt(mean_squared_error(Y_val_SR, y_predval_SR))

# Model Performance: Testing
test_r2_SS = r2_score(y_test_SS, y_predtest_SS)
test_rmse_SS = np.sqrt(mean_squared_error(y_test_SS, y_predtest_SS))

test_r2_TTF = r2_score(y_test_TTF, y_predtest_TTF)
test_rmse_TTF = np.sqrt(mean_squared_error(y_test_TTF, y_predtest_TTF))

test_r2_SR = r2_score(y_test_SR, y_predtest_SR)
test_rmse_SR = np.sqrt(mean_squared_error(y_test_SR, y_predtest_SR))

# %%
# Print R2 Results
print("R2 scores: Train (SS) - %0.5f, Train (TTF) - %0.5f, Train (SR) - %0.5f" %(train_r2_SS, train_r2_TTF, train_r2_SR))
print("R2 scores: Val (SS) - %0.5f, Val (TTF) - %0.5f, Val (SR) - %0.5f" %(val_r2_SS, val_r2_TTF, val_r2_SR))
print("R2 scores: Test (SS) - %0.5f, Test (TTF) - %0.5f, Test (SR) - %0.5f" %(test_r2_SS, test_r2_TTF, test_r2_SR))
# Out:
# R2 scores: Train (SS) - 0.97138, Train (TTF) - 0.95694, Train (SR) - 0.86269
# R2 scores: Val (SS) - 0.92865, Val (TTF) - 0.96611, Val (SR) - 0.82311
# R2 scores: Test (SS) - 0.72236, Test (TTF) - 0.87115, Test (SR) - 0.82405

# %%
# Print RMSE Results
print("RMSE: Train (SS) - %0.5f, Train (TTF) - %0.5f, Train (SR) - %0.5f" %(train_rmse_SS, train_rmse_TTF, train_rmse_SR))
print("RMSE: Val (SS) - %0.5f, Val (TTF) - %0.5f, Val (SR) - %0.5f" %(val_rmse_SS, val_rmse_TTF, val_rmse_SR))
print("RMSE: Test (SS) - %0.5f, Test (TTF) - %0.5f, Test (SR) - %0.5f" %(test_rmse_SS, test_rmse_TTF, test_rmse_SR))
# Out:
# RMSE: Train (SS) - 0.02288, Train (TTF) - 0.59435, Train (SR) - 0.54427
# RMSE: Val (SS) - 0.04146, Val (TTF) - 0.59180, Val (SR) - 0.60569
# RMSE: Test (SS) - 0.07980, Test (TTF) - 1.11545, Test (SR) - 0.57773

# %%
# Overall plot:
ttime = df['Time'][n_steps:]
t1, testtime = train_test_split(ttime, test_size=0.1, shuffle=False)
traintime, valtime = train_test_split(t1, test_size=0.111, shuffle=False)

fig = plt.figure(1, figsize=(20,6))
plt.plot(ttime, ydf_SS)
plt.plot(traintime, y_predtrain_SS)
plt.plot(valtime, y_predval_SS)
plt.plot(testtime, y_predtest_SS)
plt.xlabel('Time (s)')
plt.ylabel('Shear Stress (MPa)')
plt.legend(['Ground truth', 'Train Prediction', 'Validation Prediction', 'Test Prediction'])

fig = plt.figure(2, figsize=(20,6))
plt.plot(ttime, ydf_TTF)
plt.plot(traintime, y_predtrain_TTF)
plt.plot(valtime,  y_predval_TTF)
plt.plot(testtime, y_predtest_TTF)
plt.xlabel('Time (s)')
plt.ylabel('TTF (s)')
plt.legend(['Ground truth', 'Train Prediction', 'Validation Prediction', 'Test Prediction'])

ydf_SR = np.exp(ydf_SR)*10;
y_predtrain_SR = np.exp(y_predtrain_SR)*10;
y_predval_SR = np.exp(y_predval_SR)*10;
y_predtest_SR = np.exp(y_predtest_SR)*10;

fig = plt.figure(3, figsize=(20,6))
plt.plot(ttime, ydf_SR)
plt.plot(traintime, y_predtrain_SR)
plt.plot(valtime,  y_predval_SR)
plt.plot(testtime, y_predtest_SR)
plt.xlabel('Time (s)')
plt.ylabel('Slip Rate (um/s)')
plt.legend(['Ground truth', 'Train Prediction', 'Validation Prediction', 'Test Prediction'])

# %%
# # Individual plot: SS

def results_plot(fig_no, t, gt, pred, title, col):
  fig = plt.figure(fig_no, figsize=(20,6))
  plt.plot(t, gt)
  plt.plot(t, pred, col)
  plt.xlabel('Time (s)')
  plt.ylabel('Shear Stress (MPa)')
  plt.legend(['Ground truth', 'Predicted'])
  plt.title(title)

results_plot(1, traintime, Y_train_SS, y_predtrain_SS, 'Training data', '')
results_plot(2, valtime, Y_val_SS, y_predval_SS, 'Validation data', 'g')
results_plot(3, testtime, y_test_SS, y_predtest_SS, 'Testing data', 'r')

# %%
# # Individual plot: TTF

def results_plot(fig_no, t, gt, pred, title, col):
  fig = plt.figure(fig_no, figsize=(20,6))
  plt.plot(t, gt)
  plt.plot(t, pred, col)
  plt.xlabel('Time (s)')
  plt.ylabel('TTF (s)')
  plt.legend(['Ground truth', 'Predicted'])
  plt.title(title)

results_plot(1, traintime, Y_train_TTF, y_predtrain_TTF, 'Training data', '')
results_plot(2, valtime, Y_val_TTF, y_predval_TTF, 'Validation data', 'g')
results_plot(3, testtime, y_test_TTF, y_predtest_TTF, 'Testing data', 'r')

# %%
# # Individual plot: SR
Y_train_SR = np.exp(Y_train_SR)*10;
Y_val_SR = np.exp(Y_val_SR)*10;
y_test_SR = np.exp(y_test_SR)*10;

def results_plot(fig_no, t, gt, pred, title, col):
  fig = plt.figure(fig_no, figsize=(20,6))
  plt.plot(t, gt)
  plt.plot(t, pred, col)
  plt.xlabel('Time (s)')
  plt.ylabel('Slip Rate (um/s)')
  plt.legend(['Ground truth', 'Predicted'])
  plt.title(title)

results_plot(1, traintime, Y_train_SR, y_predtrain_SR, 'Training data', '')
results_plot(2, valtime, Y_val_SR, y_predval_SR, 'Validation data', 'g')
results_plot(3, testtime, y_test_SR, y_predtest_SR, 'Testing data', 'r')
